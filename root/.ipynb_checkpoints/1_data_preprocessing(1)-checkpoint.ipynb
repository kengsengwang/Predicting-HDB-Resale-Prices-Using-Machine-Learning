# %% [markdown]
# # Data Preprocessing Workflow

# %% [markdown]
# By: Wang Keng Seng

# %%
import pandas as pd

# Define the file path (use raw string `r""` to avoid issues with backslashes)
file_path = r"C:\Users\DELL\Documents\Predicting HDB Resale Prices Using Machine Learning\data\resale_transactions.csv"

# Load the CSV into a DataFrame
df = pd.read_csv(file_path)

# Display the first 5 rows to confirm it's loaded
print("✅ Dataset loaded successfully. Here's a preview:")
print(df.head())
# Out:
# ✅ Dataset loaded successfully. Here's a preview:
#    id    month flat_type block          street_name storey_range  \
# 0   1  2018-05    5 ROOM   118      PASIR RIS ST 11     07 TO 09
# 1   2  2016-10    4 ROOM   101       RIVERVALE WALK     01 TO 03
# 2   3  2018-10    5 ROOM  688A     CHOA CHU KANG DR     19 TO 21
# 3   4  2015-12    4 ROOM   130           LOR AH SOO     13 TO 15
# 4   5  2017-09    5 ROOM   533  SERANGOON NTH AVE 4     07 TO 09
#
#    floor_area_sqm  lease_commence_date     remaining_lease  resale_price  \
# 0           123.0                 1989  70 years 03 months      488000.0
# 1           100.0                 1999                  81      345000.0
# 2           110.0                 2002  82 years 06 months      370000.0
# 3           103.0                 1984                  67      432000.0
# 4           122.0                 1992  74 years 02 months      500000.0
#
#    town_id  flatm_id      town_name flatm_name
# 0       17         5      PASIR RIS   Improved
# 1       21         8       SENGKANG    Model A
# 2        9         5  CHOA CHU KANG   Improved
# 3       12         8        HOUGANG    Model A
# 4       22         5      SERANGOON   Improved

# %%
# Extract year from 'month' column
df['year'] = pd.to_datetime(df['month']).dt.year

# Display unique years
print("Years in dataset:", df['year'].unique())
# Out:
# Years in dataset: [2018 2016 2015 2017 2019]

# %% [markdown]
# ### ✅ Dataset Preview and Year Extraction Summary
#
# #### 🗂 **Dataset Structure (Preview of 5 Rows)**
#
# The dataset represents **HDB resale transactions** in Singapore. Each row contains a record of a resale flat, including details such as:
#
# * **ID**: Unique identifier for each record.
# * **Month**: Date of the resale (e.g., 2018-05).
# * **Flat Type**: Size of the flat (e.g., 5 ROOM, 4 ROOM).
# * **Block & Street Name**: Location information.
# * **Storey Range**: The floor range of the unit (e.g., "07 TO 09").
# * **Floor Area (sqm)**: Size of the flat in square meters.
# * **Lease Commencement Date**: Year the flat’s 99-year lease began.
# * **Remaining Lease**: Time left on the lease, shown in either formatted string or raw number.
# * **Resale Price**: Selling price of the flat.
# * **Town ID & Flat Model ID**: Encoded identifiers for town and model type.
# * **Town Name**: The area the flat is located in (e.g., PASIR RIS, SENGKANG).
# * **Flat Model Name**: Type of flat design (e.g., Improved, Model A).
#
# ---
#
# #### 🧮 **Code Execution: Extracting Years from `month` Column**
#
# Two lines of Python code were executed:
#
# 1. **Extract Year**:
#
#    ```python
#    df['year'] = pd.to_datetime(df['month']).dt.year
#    ```
#
#    * This converts the `month` column from string format (e.g., "2018-05") into a `datetime` object.
#    * It then extracts just the **year** part and creates a new column called `year`.
#
# 2. **Display Unique Years**:
#
#    ```python
#    print("Years in dataset:", df['year'].unique())
#    ```
#
#    * This prints out all the **distinct years** found in the dataset.
#
# ---
#
# ### 📅 Output:
#
# ```text
# Years in dataset: [2018 2016 2015 2017 2019]
# ```
#
# This means the dataset includes resale transactions spanning **five years**:
# **2015, 2016, 2017, 2018, and 2019**.

# %% [markdown]
# ## Average Resale Price Per Year

# %%
import matplotlib.pyplot as plt

# Group by year and calculate average resale price
avg_price_by_year = df.groupby('year')['resale_price'].mean()

# Plotting
plt.figure(figsize=(10, 6))
avg_price_by_year.plot(kind='line', marker='o')
plt.title('📈 Average HDB Resale Price by Year')
plt.xlabel('Year')
plt.ylabel('Average Resale Price (SGD)')
plt.grid(True)
plt.xticks(avg_price_by_year.index)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_19892\920647551.py:14: UserWarning: Glyph 128200 (\N{CHART WITH UPWARDS TREND}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\DELL\AppData\Local\Programs\Python\Python310\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 128200 (\N{CHART WITH UPWARDS TREND}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# ## Number of Transactions Per Year

# %%
# Group by year and count transactions
transactions_by_year = df['year'].value_counts().sort_index()

# Plotting
plt.figure(figsize=(10, 6))
transactions_by_year.plot(kind='bar', color='skyblue')
plt.title('🏠 Number of HDB Resale Transactions per Year')
plt.xlabel('Year')
plt.ylabel('Number of Transactions')
plt.xticks(rotation=0)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_19892\3899735010.py:11: UserWarning: Glyph 127968 (\N{HOUSE BUILDING}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\DELL\AppData\Local\Programs\Python\Python310\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 127968 (\N{HOUSE BUILDING}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
# Save yearly statistics to CSV
summary_df = pd.DataFrame({
    'Average_Resale_Price': avg_price_by_year,
    'Transactions': transactions_by_year
})
summary_df.to_csv('yearly_hdb_summary.csv')

# %%
import pandas as pd
import glob

# --- Load a single CSV file (specific one you're working with) ---
file_path = r"C:\Users\DELL\Documents\Predicting HDB Resale Prices Using Machine Learning\data\resale_transactions.csv"
df = pd.read_csv(file_path)
print("✅ Loaded file:", file_path)
print(df.head(), '\n')


# --- Loop through all CSVs in a folder to check schema ---
folder_path = r"C:\Users\DELL\Documents\Predicting HDB Resale Prices Using Machine Learning\data\hdb_resale"
for file in glob.glob(folder_path + r"\*.csv"):
    df = pd.read_csv(file)
    print("📄 File:", file)
    print(f"🔢 Columns: {len(df.columns)}")
    print("🧾 Column Names:", list(df.columns))
    print("🧬 Data Types:\n", df.dtypes, '\n')
# Out:
# ✅ Loaded file: C:\Users\DELL\Documents\Predicting HDB Resale Prices Using Machine Learning\data\resale_transactions.csv
#    id    month flat_type block          street_name storey_range  \
# 0   1  2018-05    5 ROOM   118      PASIR RIS ST 11     07 TO 09
# 1   2  2016-10    4 ROOM   101       RIVERVALE WALK     01 TO 03
# 2   3  2018-10    5 ROOM  688A     CHOA CHU KANG DR     19 TO 21
# 3   4  2015-12    4 ROOM   130           LOR AH SOO     13 TO 15
# 4   5  2017-09    5 ROOM   533  SERANGOON NTH AVE 4     07 TO 09
#
#    floor_area_sqm  lease_commence_date     remaining_lease  resale_price  \
# 0           123.0                 1989  70 years 03 months      488000.0
# 1           100.0                 1999                  81      345000.0
# 2           110.0                 2002  82 years 06 months      370000.0
# 3           103.0                 1984                  67      432000.0
# 4           122.0                 1992  74 years 02 months      500000.0
#
#    town_id  flatm_id      town_name flatm_name
# 0       17         5      PASIR RIS   Improved
# 1       21         8       SENGKANG    Model A
# 2        9         5  CHOA CHU KANG   Improved
# 3       12         8        HOUGANG    Model A
# 4       22         5      SERANGOON   Improved

# %% [markdown]
# Each row contains details such as:
#
# * **Month of Sale** (e.g., `2018-05`)
# * **Flat Type** (e.g., `4 ROOM`, `5 ROOM`)
# * **Block and Street Name** (e.g., `118 PASIR RIS ST 11`)
# * **Storey Range** (e.g., `07 TO 09`)
# * **Floor Area** (e.g., `123.0 sqm`)
# * **Lease Commencement Date** (e.g., `1989`)
# * **Remaining Lease** (e.g., `70 years 03 months`)
# * **Resale Price** (e.g., `$488,000`)
# * **Town and Flat Model Name** (e.g., `PASIR RIS`, `Improved`)
#
# ### 🧠 Key Insight:
#
# The dataset is well-structured and loaded correctly, ready for further steps such as:
#
# * **Data cleaning** (e.g., standardizing `remaining_lease`)
# * **Feature engineering**
# * **Model training**

# %%
import pandas as pd

# Load a specific file only
file_path = r"C:\Users\DELL\Documents\Predicting HDB Resale Prices Using Machine Learning\data\resale_transactions.csv"
df = pd.read_csv(file_path)
print('✅ Single file loaded:', file_path)
print(df.head())
# Out:
# ✅ Single file loaded: C:\Users\DELL\Documents\Predicting HDB Resale Prices Using Machine Learning\data\resale_transactions.csv
#    id    month flat_type block          street_name storey_range  \
# 0   1  2018-05    5 ROOM   118      PASIR RIS ST 11     07 TO 09
# 1   2  2016-10    4 ROOM   101       RIVERVALE WALK     01 TO 03
# 2   3  2018-10    5 ROOM  688A     CHOA CHU KANG DR     19 TO 21
# 3   4  2015-12    4 ROOM   130           LOR AH SOO     13 TO 15
# 4   5  2017-09    5 ROOM   533  SERANGOON NTH AVE 4     07 TO 09
#
#    floor_area_sqm  lease_commence_date     remaining_lease  resale_price  \
# 0           123.0                 1989  70 years 03 months      488000.0
# 1           100.0                 1999                  81      345000.0
# 2           110.0                 2002  82 years 06 months      370000.0
# 3           103.0                 1984                  67      432000.0
# 4           122.0                 1992  74 years 02 months      500000.0
#
#    town_id  flatm_id      town_name flatm_name
# 0       17         5      PASIR RIS   Improved
# 1       21         8       SENGKANG    Model A
# 2        9         5  CHOA CHU KANG   Improved
# 3       12         8        HOUGANG    Model A
# 4       22         5      SERANGOON   Improved

# %% [markdown]
# ## 🧾 **Displayed Data (First 5 Rows)**
#
# Each row represents a **single HDB resale transaction**. The dataset includes a variety of useful columns:
#
# | Column Name           | Example Value          | Description                              |
# | --------------------- | ---------------------- | ---------------------------------------- |
# | `id`                  | 1, 2, 3...             | Unique identifier for each record        |
# | `month`               | 2018-05, 2016-10...    | The year and month of the transaction    |
# | `flat_type`           | 5 ROOM, 4 ROOM         | The flat's configuration/size            |
# | `block`               | 118, 101, 688A...      | HDB block number                         |
# | `street_name`         | PASIR RIS ST 11...     | The street where the flat is located     |
# | `storey_range`        | 07 TO 09, 01 TO 03...  | The storey level range of the flat       |
# | `floor_area_sqm`      | 123.0, 100.0...        | Flat size in square meters               |
# | `lease_commence_date` | 1989, 1999...          | Year when the 99-year lease started      |
# | `remaining_lease`     | 70 years 03 months...  | Lease period left as of transaction date |
# | `resale_price`        | 488000.0, 345000.0...  | Flat resale price in SGD                 |
# | `town_id`             | 17, 21, 9...           | Numeric ID representing the town         |
# | `flatm_id`            | 5, 8...                | Numeric ID for the flat model            |
# | `town_name`           | PASIR RIS, SENGKANG... | Name of the HDB town                     |
# | `flatm_name`          | Improved, Model A      | Type of flat model or layout             |
#
# ---
#
# ## 📊 **Example Row Explanation (Row 0)**
#
# | Feature               | Value              | Meaning                          |
# | --------------------- | ------------------ | -------------------------------- |
# | `id`                  | 1                  | First transaction entry          |
# | `month`               | 2018-05            | Sold in May 2018                 |
# | `flat_type`           | 5 ROOM             | 5-room flat                      |
# | `block`               | 118                | Located in Block 118             |
# | `street_name`         | PASIR RIS ST 11    | Street in Pasir Ris              |
# | `storey_range`        | 07 TO 09           | Flat is between 7th to 9th floor |
# | `floor_area_sqm`      | 123.0              | 123 square meters                |
# | `lease_commence_date` | 1989               | Lease began in 1989              |
# | `remaining_lease`     | 70 years 03 months | Lease left at time of sale       |
# | `resale_price`        | 488000.0           | Sold for SGD 488,000             |
# | `town_name`           | PASIR RIS          | Located in Pasir Ris             |
# | `flatm_name`          | Improved           | "Improved" flat model            |

# %%
import pandas as pd

file_path = r"C:\Users\DELL\Documents\Predicting HDB Resale Prices Using Machine Learning\data\resale_transactions.csv"
df = pd.read_csv(file_path)
print("✅ Loaded single file:", file_path)
print(df.head())
# Out:
# ✅ Loaded single file: C:\Users\DELL\Documents\Predicting HDB Resale Prices Using Machine Learning\data\resale_transactions.csv
#    id    month flat_type block          street_name storey_range  \
# 0   1  2018-05    5 ROOM   118      PASIR RIS ST 11     07 TO 09
# 1   2  2016-10    4 ROOM   101       RIVERVALE WALK     01 TO 03
# 2   3  2018-10    5 ROOM  688A     CHOA CHU KANG DR     19 TO 21
# 3   4  2015-12    4 ROOM   130           LOR AH SOO     13 TO 15
# 4   5  2017-09    5 ROOM   533  SERANGOON NTH AVE 4     07 TO 09
#
#    floor_area_sqm  lease_commence_date     remaining_lease  resale_price  \
# 0           123.0                 1989  70 years 03 months      488000.0
# 1           100.0                 1999                  81      345000.0
# 2           110.0                 2002  82 years 06 months      370000.0
# 3           103.0                 1984                  67      432000.0
# 4           122.0                 1992  74 years 02 months      500000.0
#
#    town_id  flatm_id      town_name flatm_name
# 0       17         5      PASIR RIS   Improved
# 1       21         8       SENGKANG    Model A
# 2        9         5  CHOA CHU KANG   Improved
# 3       12         8        HOUGANG    Model A
# 4       22         5      SERANGOON   Improved

# %% [markdown]
# ### 📋 **Displayed Data (First 5 Rows)**
#
# Each row represents a **resale transaction of an HDB flat in Singapore**. Here's a breakdown of the columns shown:
#
# ---
#
# #### 🧾 **Flat Information**
#
# | Column         | Example Value         | Description                            |
# | -------------- | --------------------- | -------------------------------------- |
# | `id`           | 1, 2, 3, ...          | Unique identifier for each transaction |
# | `month`        | 2018-05, 2016-10, ... | The month and year of the resale       |
# | `flat_type`    | 5 ROOM, 4 ROOM        | The type of flat (size)                |
# | `block`        | 118, 101, 688A        | Block number where the flat is located |
# | `street_name`  | PASIR RIS ST 11, ...  | Name of the street                     |
# | `storey_range` | 07 TO 09, 01 TO 03    | Floor level range of the flat          |
#
# ---
#
# #### 📐 **Flat Attributes**
#
# | Column                | Example Value          | Description                              |
# | --------------------- | ---------------------- | ---------------------------------------- |
# | `floor_area_sqm`      | 123.0, 100.0           | Floor area in square meters              |
# | `lease_commence_date` | 1989, 1999             | Start year of the 99-year lease          |
# | `remaining_lease`     | 70 years 03 months, 81 | Lease period left at time of transaction |
# | `resale_price`        | 488000.0, 345000.0     | Price of the resale in SGD               |
#
# ---
#
# #### 🌍 **Location & Model Info**
#
# | Column       | Example Value       | Description               |
# | ------------ | ------------------- | ------------------------- |
# | `town_id`    | 17, 21, 9           | Numerical ID for the town |
# | `flatm_id`   | 5, 8                | Flat model ID             |
# | `town_name`  | PASIR RIS, SENGKANG | Town or estate name       |
# | `flatm_name` | Improved, Model A   | Flat model classification |
#
# ---
#
# ### ✅ Key Takeaways
#
# * The data structure is consistent and readable.
# * The dataset includes useful features for resale price prediction.
# * Some columns (like `remaining_lease`) may need **cleaning or transformation** to numeric format.

# %% [markdown]
# ## Feeling the data out

# %%
df.shape
# Out:
# (88688, 14)

# %%
import pandas as pd

# Load the dataset
file_path = r"C:\Users\DELL\Documents\Predicting HDB Resale Prices Using Machine Learning\data\resale_transactions.csv"
df = pd.read_csv(file_path)

# Display the shape of the DataFrame
print("✅ Dataset shape (rows, columns):", df.shape)
# Out:
# ✅ Dataset shape (rows, columns): (88688, 14)

# %%
df.head()
# Out:
#    id    month flat_type block          street_name storey_range  \
# 0   1  2018-05    5 ROOM   118      PASIR RIS ST 11     07 TO 09
# 1   2  2016-10    4 ROOM   101       RIVERVALE WALK     01 TO 03
# 2   3  2018-10    5 ROOM  688A     CHOA CHU KANG DR     19 TO 21
# 3   4  2015-12    4 ROOM   130           LOR AH SOO     13 TO 15
# 4   5  2017-09    5 ROOM   533  SERANGOON NTH AVE 4     07 TO 09
#
#    floor_area_sqm  lease_commence_date     remaining_lease  resale_price  \
# 0           123.0                 1989  70 years 03 months      488000.0
# 1           100.0                 1999                  81      345000.0
# 2           110.0                 2002  82 years 06 months      370000.0
# 3           103.0                 1984                  67      432000.0
# 4           122.0                 1992  74 years 02 months      500000.0
#
#    town_id  flatm_id      town_name flatm_name
# 0       17         5      PASIR RIS   Improved
# 1       21         8       SENGKANG    Model A
# 2        9         5  CHOA CHU KANG   Improved
# 3       12         8        HOUGANG    Model A
# 4       22         5      SERANGOON   Improved

# %% [markdown]
# * `month`, `flat_type`, `block`, `street_name`, `storey_range`
# * `floor_area_sqm`, `lease_commence_date`, `remaining_lease`
# * `resale_price`, `town_id`, `flatm_id`, `town_name`, `flatm_name`
#
# A key observation is noted beneath the table:
#
# > "Notice that the column `'remaining_lease'` contains mostly NaNs. This feature does not ring any bells on how useful it can be, so we will delete it for the time being."
#
# This remark highlights a **data quality issue** — the `remaining_lease` column has inconsistent formats:
#
# * Some entries are in string format like `"70 years 03 months"`.
# * Others appear as plain numbers (e.g., `81`, `67`).
# * As a result, the column has missing values (`NaN`) and may be dropped temporarily for analysis.

# %% [markdown]
# ## HDB Resale Data Preprocessing: Safe Column Dropping and Address Extraction

# %%
import pandas as pd

# Load the resale transactions CSV file
file_path = r"C:\Users\DELL\Documents\Predicting HDB Resale Prices Using Machine Learning\data\resale_transactions.csv"
df = pd.read_csv(file_path)

# ✅ Safely drop 'remaining_lease' column if it exists
if 'remaining_lease' in df.columns:
    df = df.drop(columns=['remaining_lease'])
    print("✅ 'remaining_lease' column dropped.")
else:
    print("⚠️ 'remaining_lease' column not found — nothing to drop.")

# 🧾 Check data types for confirmation
print("\n📋 DataFrame dtypes:\n", df.dtypes)

# ✅ Create a new 'full_address' column
df['full_address'] = df['block'].map(str) + ' ' + df['street_name'].map(str)

# ✅ Get unique full addresses
full_address_list = df['full_address'].unique().tolist()
print("\n📦 Number of unique full addresses:", len(full_address_list))

# ✅ Display one sample address
print("🏠 Sample address:", full_address_list[1])

# ✅ Create a test subset of addresses (1 to 199)
test_address_list = full_address_list[1:200]
print("\n🔍 Test address list (sample):")
print(test_address_list)
# Out:
# ✅ 'remaining_lease' column dropped.
#
# 📋 DataFrame dtypes:
#  id                       int64
# month                   object
# flat_type               object
# block                   object
# street_name             object
# storey_range            object
# floor_area_sqm         float64
# lease_commence_date      int64
# resale_price           float64
# town_id                  int64
# flatm_id                 int64
# town_name               object
# flatm_name              object
# dtype: object
#
# 📦 Number of unique full addresses: 8647
# 🏠 Sample address: 101 RIVERVALE WALK
#
# 🔍 Test address list (sample):
# ['101 RIVERVALE WALK', '688A CHOA CHU KANG DR', '130 LOR AH SOO', '533 SERANGOON NTH AVE 4', '503 ANG MO KIO AVE 5', '264 BISHAN ST 24', '602 BEDOK RESERVOIR RD', "20 ST. GEORGE'S RD", '311B ANCHORVALE LANE', '201 ANG MO KIO AVE 3', '322 SERANGOON AVE 3', '208 BOON LAY PL', '528 BT BATOK ST 51', '410C FERNVALE RD', '219A BEDOK CTRL', '162 MEI LING ST', '18 TECK WHYE LANE', '686A CHOA CHU KANG CRES', '655 YISHUN AVE 4', "88 C'WEALTH CL", '287D JURONG EAST ST 21', '619D PUNGGOL DR', '266 BISHAN ST 24', '249 YISHUN AVE 9', '527 JELAPANG RD', '275C COMPASSVALE LINK', '406 WOODLANDS ST 41', '126 LOR 1 TOA PAYOH', '676A JURONG WEST ST 64', '33 TEBAN GDNS RD', '206 PETIR RD', '275 BANGKIT RD', '289 CHOA CHU KANG AVE 3', '691 JURONG WEST CTRL 1', '467 ADMIRALTY DR', '469 JURONG WEST ST 41', '219D BEDOK CTRL', '443C FERNVALE RD', '845 WOODLANDS ST 82', '306 ANG MO KIO AVE 1', '57 NEW UPP CHANGI RD', '719 BEDOK RESERVOIR RD', '107 BISHAN ST 12', '99 BEDOK NTH AVE 4', '19 HOUGANG AVE 3', '162B PUNGGOL CTRL', '705 CLEMENTI WEST ST 2', '251 KIM KEAT LINK', '628 JURONG WEST ST 65', '5 HAIG RD', '206A COMPASSVALE LANE', '143 LOR 2 TOA PAYOH', '329 CLEMENTI AVE 2', '431B YISHUN AVE 1', '135 LOR AH SOO', '185B RIVERVALE CRES', '1 TELOK BLANGAH CRES', '851 YISHUN ST 81', '552 ANG MO KIO AVE 10', '13 DOVER CL EAST', '686B WOODLANDS DR 73', "20 QUEEN'S CL", '104 JURONG EAST ST 13', '832 HOUGANG CTRL', '523 BEDOK NTH ST 3', '117 CLEMENTI ST 13', '62A STRATHMORE AVE', '58 DAKOTA CRES', '338 TAMPINES ST 33', '526 BEDOK NTH ST 3', '259 ANG MO KIO AVE 2', '612C PUNGGOL DR', '254 BT BATOK EAST AVE 4', '472 SEGAR RD', '2 DELTA AVE', '454 HOUGANG AVE 10', '215 ANG MO KIO AVE 1', '835 YISHUN ST 81', '360 BT BATOK ST 31', '105 WOODLANDS ST 13', '418 ANG MO KIO AVE 10', '276 TOH GUAN RD', '114 HO CHING RD', '435B FERNVALE RD', '786E WOODLANDS DR 60', '897C WOODLANDS DR 50', '189 BT BATOK WEST AVE 6', "15 ST. GEORGE'S RD", '436D FERNVALE RD', '501D WELLINGTON CIRCLE', '267 BT BATOK EAST AVE 4', '714 JURONG WEST ST 71', '862 TAMPINES ST 83', '415 ANG MO KIO AVE 10', '66 BEDOK STH AVE 3', '577 ANG MO KIO AVE 10', '561 PASIR RIS ST 51', '167D PUNGGOL EAST', '617A PUNGGOL DR', '157 MEI LING ST', '272 BT BATOK EAST AVE 4', '201E TAMPINES ST 23', '10 MARSILING DR', '518 WOODLANDS DR 14', '146 SERANGOON NTH AVE 1', '5A MARSILING DR', '339D KANG CHING RD', '4 HOLLAND CL', '847 TAMPINES ST 83', '618 ANG MO KIO AVE 4', '114 HOUGANG AVE 1', '425 BEDOK NTH RD', '274D PUNGGOL PL', '450F TAMPINES ST 42', '274 YISHUN ST 22', '653C JURONG WEST ST 61', '80A TELOK BLANGAH ST 31', '508 BT BATOK ST 52', '183C BOON LAY AVE', '640 ROWELL RD', '508 WOODLANDS DR 14', '638 YISHUN ST 61', '989B JURONG WEST ST 93', '5 TELOK BLANGAH CRES', '861A TAMPINES AVE 5', '346 YISHUN AVE 11', '19 BEDOK STH RD', '724 PASIR RIS ST 72', '3B UPP BOON KENG RD', '319C ANCHORVALE DR', '826 JURONG WEST ST 81', '383 TAMPINES ST 32', '340B SEMBAWANG CL', '102 WOODLANDS ST 13', '687C WOODLANDS DR 75', '103 BEDOK RESERVOIR RD', '335A SMITH ST', '12 TELOK BLANGAH CRES', '339 WOODLANDS AVE 1', '828 WOODLANDS ST 81', '858 WOODLANDS ST 83', '766 JURONG WEST ST 74', '138C LOR 1A TOA PAYOH', '554 HOUGANG ST 51', '310 CANBERRA RD', '357 YUNG AN RD', '290C COMPASSVALE CRES', '533 UPP CROSS ST', '682 HOUGANG AVE 4', '482 ADMIRALTY LINK', '26B JLN MEMBINA', '270A PUNGGOL FIELD', '504 BEDOK NTH ST 3', '502 BEDOK NTH ST 3', '210 TAMPINES ST 23', '213A COMPASSVALE LANE', '195 KIM KEAT AVE', '219 TAMPINES ST 24', '161 MEI LING ST', '312 SEMBAWANG DR', '19 JLN MEMBINA', '110 BEDOK RESERVOIR RD', '709 TAMPINES ST 71', '441D FERNVALE RD', '722 PASIR RIS ST 72', '237 BT PANJANG RING RD', '634 ANG MO KIO AVE 6', '539 BEDOK NTH ST 3', '446B JLN KAYU', '410B FERNVALE RD', '236A SERANGOON AVE 2', '199 TOA PAYOH NTH', '209C PUNGGOL PL', '57 CIRCUIT RD', '480 PASIR RIS DR 4', '180 BT BATOK WEST AVE 8', '525 SERANGOON NTH AVE 4', '17 JLN TENTERAM', '518 JURONG WEST ST 52', '285D TOH GUAN RD', '819 TAMPINES ST 81', '157 YISHUN ST 11 ...

# %% [markdown]
# ## Batch Geocoding

# %% [markdown]
# ## Batch Geocoding refers to the process of converting a large list of physical addresses into geographic coordinates (latitude and longitude) using a geolocation API — in this case, OneMap Singapore API.
#
# Instead of processing one address at a time, batch geocoding automates the task for hundreds or thousands of addresses, looping through them and retrieving their corresponding coordinates efficiently.
# 📍 Use Case:
#
# You want to find the latitude and longitude for each HDB block address so you can:
#
#     Visualize resale flats on a map
#
#     Calculate distances to MRT stations or schools
#
#     Perform spatial clustering or geospatial analytics

# %%
import pandas as pd
import requests
import time

# Load the resale data
file_path = r"C:\Users\DELL\Documents\Predicting HDB Resale Prices Using Machine Learning\data\resale_transactions.csv"
df = pd.read_csv(file_path)

# Step 1: Create full address
df['full_address'] = df['block'].astype(str) + ' ' + df['street_name'].astype(str)

# Step 2: Get unique full addresses
full_address_list = df['full_address'].unique().tolist()

# Step 3: Setup OneMap API query
query_results = []
url = "https://developers.onemap.sg/commonapi/search"

# Step 4: Loop through each address and request geocoding data
for address in full_address_list:
    query_params = {
        "searchVal": address,
        "returnGeom": "Y",
        "getAddrDetails": "Y",
        "pageNum": "1"
    }
    
    try:
        response = requests.get(url, params=query_params)
        if response.status_code == 200:
            data = response.json()
            if data['found'] > 0:
                # Attach address + first result
                first_result = data['results'][0]
                result_entry = {
                    "address": address,
                    "latitude": first_result["LATITUDE"],
                    "longitude": first_result["LONGITUDE"],
                    "postal": first_result.get("POSTAL", None)
                }
                query_results.append(result_entry)
            else:
                query_results.append({"address": address, "latitude": None, "longitude": None})
        else:
            print(f"❌ Failed for: {address} | Status code: {response.status_code}")
    except Exception as e:
        print(f"❌ Exception for address {address}: {e}")
        query_results.append({"address": address, "latitude": None, "longitude": None})

    time.sleep(0.2)  # Sleep to respect rate limits (OneMap allows 250 requests/min)

print("✅ Batch geocoding completed.")
# Out:
# ❌ Exception for address 118 PASIR RIS ST 11: HTTPSConnectionPool(host='developers.onemap.sg', port=443): Max retries exceeded with url: /commonapi/search?searchVal=118+PASIR+RIS+ST+11&returnGeom=Y&getAddrDetails=Y&pageNum=1 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000020551CDCDF0>: Failed to resolve 'developers.onemap.sg' ([Errno 11002] getaddrinfo failed)"))
# ❌ Exception for address 101 RIVERVALE WALK: HTTPSConnectionPool(host='developers.onemap.sg', port=443): Max retries exceeded with url: /commonapi/search?searchVal=101+RIVERVALE+WALK&returnGeom=Y&getAddrDetails=Y&pageNum=1 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000020551CDD870>: Failed to resolve 'developers.onemap.sg' ([Errno 11002] getaddrinfo failed)"))
# ❌ Exception for address 688A CHOA CHU KANG DR: HTTPSConnectionPool(host='developers.onemap.sg', port=443): Max retries exceeded with url: /commonapi/search?searchVal=688A+CHOA+CHU+KANG+DR&returnGeom=Y&getAddrDetails=Y&pageNum=1 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000002054E01C7F0>: Failed to resolve 'developers.onemap.sg' ([Errno 11002] getaddrinfo failed)"))
# ❌ Exception for address 130 LOR AH SOO: HTTPSConnectionPool(host='developers.onemap.sg', port=443): Max retries exceeded with url: /commonapi/search?searchVal=130+LOR+AH+SOO&returnGeom=Y&getAddrDetails=Y&pageNum=1 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000020551CDD270>: Failed to resolve 'developers.onemap.sg' ([Errno 11002] getaddrinfo failed)"))
# ❌ Exception for address 533 SERANGOON NTH AVE 4: HTTPSConnectionPool(host='developers.onemap.sg', port=443): Max retries exceeded with url: /commonapi/search?searchVal=533+SERANGOON+NTH+AVE+4&returnGeom=Y&getAddrDetails=Y&pageNum=1 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000020551CDE0B0>: Failed to resolve 'developers.onemap.sg' ([Errno 11002] getaddrinfo failed)"))
# ❌ Exception for address 503 ANG MO KIO AVE 5: HTTPSConnectionPool(host='developers.onemap.sg', port=443): Max retries exceeded with url: /commonapi/search?searchVal=503+ANG+MO+KIO+AVE+5&returnGeom=Y&getAddrDetails=Y&pageNum=1 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000020551CDE830>: Failed to resolve 'developers.onemap.sg' ([Errno 11002] getaddrinfo failed)"))
# ❌ Exception for address 264 BISHAN ST 24: HTTPSConnectionPool(host='developers.onemap.sg', port=443): Max retries exceeded with url: /commonapi/search?searchVal=264+BISHAN+ST+24&returnGeom=Y&getAddrDetails=Y&pageNum=1 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000020551CDF070>: Failed to resolve 'developers.onemap.sg' ([Errno 11002] getaddrinfo failed)"))
# ❌ Exception for address 602 BEDOK RESERVOIR RD: HTTPSConnectionPool(host='developers.onemap.sg', port=443): Max retries exceeded with url: /commonapi/search?searchVal=602+BEDOK+RESERVOIR+RD&returnGeom=Y&getAddrDetails=Y&pageNum=1 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000020551D0DA80>: Failed to resolve 'developers.onemap.sg' ([Errno 11002] getaddrinfo failed)"))
# ❌ Exception for address 20 ST. GEORGE'S RD: HTTPSConnectionPool(host='developers.onemap.sg', port=443): Max retries exceeded with url: /commonapi/search?searchVal=20+ST.+GEORGE%27S+RD&returnGeom=Y&getAddrDetails=Y&pageNum=1 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000020551CDE9E0>: Failed to resolve 'developers.onemap.sg' ([Errno 11002] getaddrinfo failed)"))
# ❌ Exception for address 311B ANCHORVALE LANE: HTTPSConnectionPool(host='developers.onemap.sg', port=443): Max retries exceeded with url: /commonapi/search?searchVal=311B+ANCHORVALE+LANE&returnGeom=Y&getAddrDetails=Y&pageNum=1 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000020551CDE500>: Failed to resolve 'developers.onemap.sg' ([Errno 11002] getaddrinfo failed)"))
# ❌ Exception for address 201 ANG MO KIO AVE 3: HTTPSConnectionPool(host='developers.onemap.sg', port=443): Max retries exceeded with url: /commonapi/search?searchVal=201+ANG+MO+KIO+AVE+3&returnGeom=Y&getAddrDetails=Y&pageNum=1 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000020551CDCDF0>: Failed to resolve 'developers.onemap.sg' ([Errno 11002] getaddrinfo failed)"))
# ❌ Exception for address 322 SERANGOON AVE 3: HTTPSConnectionPool(host='developers.onemap.sg', port=443): Max retries exceeded with url: /commonapi/search?searchVal=322+SERANGOON+AVE+3&returnGeom=Y&getAddrDetails=Y&pageNum=1 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000020551CDD6C0>: Failed to resolve 'developers.onemap.sg' ([Errno 11002] getaddrinfo failed)"))
# ❌ Exception for address 208 BOON LAY PL: HTTPSConnectionPool(host='developers.onemap.sg', port=443): Max retries exceeded with url: /commonapi/search?searchVal=208+BOON+LAY+PL&returnGeom=Y&getAddrDetails=Y&pageNum=1 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000020551CDF820>: Failed to resolve 'developers.onemap.sg' ([Errno 11002] getaddrinfo failed)"))
# ❌ Exception for address 528 BT BATOK ST 51: HTTPSConnectionPool(host='developers.onemap.sg', port=443): Max retries exceeded with url: /commonapi/search?searchVal=528+BT+BATOK+ST+51&returnGeom=Y&getAddrDetails=Y&pageNum=1 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000020551CDF8B0>: Failed to resolve 'developers.onemap.sg' ([Errno 11002] getaddrinfo failed)"))
# ❌ Exception for address 410C FERNVALE RD: HTTPSConnectionPool(host='developers.onemap.sg', port=443): Max retries exceeded with url: /commonapi/search?searchVal=410C+FERNVALE+RD&returnGeom=Y&getAddrDetails=Y&pageNum=1 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000020551CDCDC0>: Failed to resolve 'developers.onemap.sg' ([Errno 11002] getaddrinfo failed)"))
# ❌ Exception for address 219A BEDOK CTRL: HTTPSConnectionPool(host='developers.onemap.sg', port=443): Max retries exceeded with url: /commonapi/search?searchVal=219A+BEDOK+CTRL&returnGeom=Y&getAddrDetails=Y&pageNum=1 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000020551CDE110>: Failed to resolve 'developers.onemap.sg' ([Errno 11002] getaddrinfo failed)"))
# ❌ Exception for address 162 MEI LING ST: HTTPSConnectionPool(host='developers.onemap.sg', port=443): Max retries exceeded with url: /commonapi/search?searchVal=162+MEI+LING+ST&returnGeom=Y&getAddrDetails=Y&pageNum=1 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000020551CDE6B0>: Failed to resolve 'developers.onemap.sg' ([Errno 11002] getaddrinfo failed)"))
# ❌ Exception for address 18 TECK WHYE LANE: HTTPSConnectionPool(host='developers.onemap.sg', port=443): Max retries exceeded with url: /commonapi/search?searchVal=18+TECK+WHYE+LANE&returnGeom=Y&getAddrDetails=Y&pageNum=1 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000020551CDF610>: Failed to resolve 'developers.onemap.sg' ([Errno 11002] getaddrinfo failed)"))
# ❌ Exception for address 686A CHOA CHU KANG CRES: HTTPSConnectionPool(host='developers.onemap.sg', port=443): Max retries exceeded with url: /commonapi/search?searchVal=686A+CHOA+CHU+KANG+CRES&returnGeom=Y&getAddrDetails=Y&pageNum=1 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000020551CDF280>: Failed to resolve 'developers.onemap.sg' ([Errno 11002] getaddrinfo failed)"))
# ❌ Exception for address 655 YISHUN AVE 4: HTTPSConnectionPool(host='developers.onemap.sg', port=443): Max retries exceeded with url: /commonapi/search?searchVal=655+YISHUN+AVE+4&returnGeom=Y&getAddrDetails=Y&pageNum=1 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000020551CDE710>: Failed to resolve 'developers.onemap.sg' ([Errno 11002] getaddrinfo failed)"))
# ❌ Exception for address 88 C'WEALTH CL: HTTPSConnectionPool(host='developers.onemap.sg', port=443): Max retries exceeded with url: /commonapi/search?searchVal=88+C%27WEALTH+CL&returnGeom=Y&getAddrDetails=Y&pageNum=1 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000020551CDE1A0>: Failed to resolve 'developers.onemap.sg' ([Errno 11002] getaddrinfo failed)"))
# ❌ Exception for address 287D JURONG EAST ST 21: HTTPSConnectionPool(host='developers.onemap.sg', port=443): Max retries exceeded with url: /commonapi/search?searchVal=287D+JURONG+EAST+ST+21&returnGeom=Y&getAddrDetails=Y&pageNum=1 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000020551CDD060>: Failed to resolve 'developers.onemap.sg' ([Errno 11002] getaddrinfo failed)"))
# ❌ Exception for address 619D PUNGGOL DR: HTTPSConnectionPool(host='developers.onemap.sg', port=443): Max retries exceeded with url: /commonapi/search?searchVal=619D+PUNGGOL+DR&returnGeom=Y&getAddrDetails=Y&pageNum=1 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000020551CDD330>: Failed to resolve 'developers.onemap.sg' ([Errno 11002] getaddrinfo failed)"))
# ❌ Exception for address 266 BISHAN ST 24: HTTPSConnectionPool(host='developers.onemap.sg', port=443): Max retries exceeded with url: /commonapi/search?searchVal=266+BISHAN+ST+24&returnGeom=Y&getAddrDetails=Y&pageNum=1 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000020551CDFB50>: Failed to resolve 'developers.onemap.sg' ([Errno 11002] getaddrinfo failed)"))
# ❌ Exception for address 249 YISHUN AVE 9: HTTPSConnectionPool(host='developers.onemap.sg', port=443): Max retries exceeded with url: /commonapi/search?searchVal=249+YISHUN+AVE+9&returnGeom=Y&getAddrDetails=Y&pageNum=1 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000020552167FD0>: Failed to resolve 'developers.onemap.sg' ([Errno 11002] getaddrinfo failed)"))
# ❌ Exception for address 527 JELAPANG RD: HTTPSConnectionPool(host='developers.onemap.sg', port=443): Max retries exceeded with url: /commonapi/search?searchVal=527+JELAPANG+RD&returnGeom=Y&getAddrDetails=Y&pageNum=1 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000020551CDF790>: Failed to resolve 'developers.onemap.sg' ([Errno 11002] getaddrinfo failed)"))
# ❌ Exception for address 275C COMPASSVALE LINK: HTTPSConnectionPool(host='developers.onemap.sg', port=443): Max retries exceeded with url: /commonapi/search?searchVal=275C+COMPASSVALE+LINK&returnGeom=Y&getAddrDetails=Y&pageNum=1 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000020551CDD2A0>: Failed to resolve 'developers.onemap.sg' ([Errno 11002] getaddrinfo failed)"))
# ❌ Exception for address 406 WOODLANDS ST 41: HTTPSConnectionPool(host='developers.onemap.sg', port=443): Max retries exceeded with url: /commonapi/search?searchVal=406+WOODLANDS+ST+41&returnGeom=Y&getAddrDetails=Y&pageNum=1 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000020551CDE140>: Failed to resolve 'developers.onemap.sg' ([Errno 11002] getaddrinfo failed)"))
# ❌ Exception for address 126 LOR 1 TOA PAYOH: HTTPSConnectionPool(host='developers.onemap.sg', port=443): Max retries exceeded with url: /commonapi/search?searchVal=126+LOR+1+TOA+PAYOH&returnGeom=Y&getAddrDetails=Y&pageNum=1 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000020551CDE290>: Failed to resolve 'developers.onemap.sg' ([Errno 11002] getaddrinfo failed)"))
# ❌ Exception for address 676A JURONG WEST ST 64: HTTPSConnectionPool(host='developers.onemap.sg', port=443): Max retries exceeded with url: /commonapi/search?searchVal=676A+JURONG+WEST+ST+64&returnGeom=Y&getAddrDetails=Y&pageNum=1 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000020551CDFF10>: Failed to resolve 'developers.onemap.sg' ([Errno 11002] getaddrinfo failed)"))
# ❌ Exception for address 33 TEBAN GDNS RD: HTTPSConnectionPool(host='developers.onemap.sg', port=443): Max retries exceeded with url: /commonapi/search?searchVal=33+TEBAN+GDNS+RD&returnGeom=Y&getAddrDetails=Y&pageNum=1 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000020551CDD360>: Failed to resolve 'developers.onemap.sg' ([Errno 11002] getaddrinfo failed)"))
# ❌ Exception for address 206 PETIR RD: HTTPSConnectionPool(host='developers.onemap.sg', port=443): Max retries exceeded with url: /commonapi/search?searchVal=206+PETIR+RD&returnGeom=Y&getAddrDetails=Y&pageNum=1 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000020551CDD420>: Failed to resolve 'developers.onemap.sg' ([Errno 11002] getaddrinfo failed)"))
# ❌ Exception for address 275 BANGKIT RD: HTTPSConnectionPool(host='developers.onemap.sg', port=443): Max retries exceeded with url: /commonapi/search?searchVal=275+BANGKIT+RD&returnGeom=Y&getAddrDetails=Y&pageNum=1 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000020551CDF820>: Failed to resolve 'developers.onemap.sg' ([Errno 11002] getaddrinfo failed)"))
# ❌ Exception for address 289 CHOA CHU KANG AVE 3: HTTPSConnectionPool(host='developers.onemap.sg', port=443): Max retries exceeded with url: /commonapi/search?searchVal=289+CHOA+CHU+KANG+AVE+3&returnGeom=Y&getAddrDetails=Y&pageNum=1 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000020551CDD990>: Failed to resolve 'developers.onemap.sg' ([Errno 11002] getaddrinfo failed)"))
# ❌ Exception for address 691 JURONG WEST CTRL 1: HTTPSConnectionPool(host='developers.onemap.sg', port=443): Max retries exceeded with url: /commonapi/search?searchVal=691+JURONG+WEST+CTRL+1&returnGeom=Y&getAddrDetails=Y&pageNum=1 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000002054E01C7F0>: Failed to resolve 'developers.onemap.sg' ([Errno 11002] getaddrinfo failed)"))
# ❌ Exception for address 467 ADMIRALTY DR: HTTPSConnectionPool(host='developers.onemap.sg', port=443): Max retries exceeded with url: /commonapi/search?searchVal=467+ADMIRALTY+DR&returnGeom=Y&getAddrDetails=Y&pageNum=1 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000020551CDFB50>: Failed to resolve 'developers.onemap.sg' ([Errno 11002] getaddrinfo failed)"))
# ❌ Exception for address 469 JURONG WEST ST 41: HTTPSConnectionPool(host='developers.onemap.sg', port=443): Max retries exceeded with url: /commonapi/search?searchVal=469+JURONG+WEST+ST+41&returnGeom=Y&getAddrDetails=Y&pageNum=1 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000020551CDFD00>: Failed to resolve 'developers.onemap.sg' ([Errno 11002] getaddrinfo failed)"))
# ❌ Exception for address 219D BEDOK CTRL: HTTPSConnectionPool(host='developers.onemap.sg', port=443): Max retries exceeded with url: /commonapi/search?searchVal=219D+BEDOK+CTRL&returnGeom=Y&getAddrDetails=Y&pageNum=1 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000020551CDFA60>: Failed to resolve 'developers.onemap.sg' ([Errno 11002] getaddrinfo failed)"))
# ❌ Exception for address 443C FERNVALE RD: HTTPSConnectionPool(host='developers.onemap.sg', port=443): Max retries exceeded with url: /commonapi/search?searchVal=443C+FERNVALE+RD&returnGeom=Y&getAddrDetails=Y&pageNum=1 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000020551CDE380>: Failed to resolve 'developers.onemap.sg' ([Errno 11002] getaddrinfo failed)"))
# ❌ Exception for address 845 WOODLANDS ST 82: HTTPSConnectionPool(host='developers.onemap.sg', port=443): Max retries exceeded with url: /commonapi/search?searchVal=845+WOODLANDS+ST+82&returnGeom=Y&getAddrDetails=Y&pageNum=1 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000020551CDE200>: Failed to resolve 'developers.onemap.sg' ([Errno 11002] getaddrinfo failed)"))
# ❌ Exception for address 306 ANG MO KIO AVE 1: HTTPSConnectionPool(host='developers.onemap.sg', port=443): Max retries exceeded with url: /commonapi/search?searchVal=306+ANG+MO+KIO+AVE+1&returnGeom=Y&getAddrDetails=Y&pageNum=1 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x00000205521F07F0>: Failed to resolve 'developers.onemap.sg' ([Errno 11002] getaddrinfo failed)"))
# ❌ Exception for address 57 NEW UPP CHANGI RD: HTTPSConnectionPool(host='developers.onemap.sg', port=443): Max retries exceeded with url: /commonapi/search?searchVal=57+NEW+UPP+CHANGI+RD&returnGeom=Y&getAddrDetails=Y&pageNum=1 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000020551CDE440>: Failed to resolve 'developers.onemap.sg' ([Errno 11002] getaddrinfo failed)"))
# ❌ Exception for address 719 BEDOK RESERVOIR RD: HTTPSConnectionPool(host='developers.onemap.sg', port=443): Max retries exceeded with url: /commonapi/search?searchVal=719+BEDOK+RESERVOIR+RD&returnGeom=Y&getAddrDetails=Y&pageNum=1 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000020551CDD0F0>: Failed to resolve 'developers.onemap.sg' ([Errno 11002] getaddrinfo failed)"))
# ❌ Exception for address 107 BISHAN ST 12: HTTPSConnectionPool(host='developers.onemap.sg', port=443): Max retries exceeded with url: /commonapi/search?searchVal=107+BISHAN+ST+12&returnGeom=Y&getAddrDetails=Y&pageNum=1 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000020551CDD540>: Failed to resolve 'developers.onemap.sg' ([Errno 11002] getaddrinfo failed)"))
# ❌ Exception for address 99 BEDOK NTH AVE 4: HTTPSConnectionPool(host='developers.onemap.sg', port=443): Max retries exceeded with url: /commonapi/search?searchVal=99+BEDOK+NTH+AVE+4&returnGeom=Y&getAddrDetails=Y&pageNum=1 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000020551CDDB40>: Failed to resolve 'developers.onemap.sg' ([Errno 11002] getaddrinfo failed)"))
# ❌ Exception for address 19 HOUGANG AVE 3: HTTPSConnectionPool(host='developers.onemap.sg', port=443): Max retries exceeded with url: /commonapi/search?searchVal=19+HOUGANG+AVE+3&returnGeom=Y&getAddrDetails=Y&pageNum=1 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000020552167FD0>: Failed to resolve 'developers.onemap.sg' ([Errno 11002] getaddrinfo failed)"))
# ❌ Exception for address 162B PUNGGOL CTRL: HTTPSConnectionPool(host='developers.onemap.sg', port=443): Max retries exceeded with url: /commonapi/search?searchVal=162B+PUNGGOL+CTRL&returnGeom=Y&getAddrDetails=Y&pageNum=1 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x00000205521F0370>: Failed to resolve 'developers.onemap.sg' ([Errno 11002] getaddrinfo failed)"))
# ❌ Exception for address 705 CLEMENTI WEST ST 2: HTTPSConnectionPool(host='developers.onemap.sg', port=443): Max retries exceeded with url: /commonapi/search?searchVal=705+CLEMENTI+WEST+ST+2&returnGeom=Y&getAddrDetails=Y&pageNum=1 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000020551CDF8B0>: Failed to resolve 'developers.onemap.sg' ([Errno 11002] getaddrinfo failed)"))
# ❌ Exception for address 251 KIM KEAT LINK: HTTPSConnectionPool(host='developers.onemap.sg', port=443): Max retries exceeded with url: /commonapi/search?searchVal=251+KIM+KEAT+LINK&returnGeom=Y&getAddrDetails=Y&pageNum=1 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000020551CDF790>: Failed to resolve 'developers.onemap.sg' ([Errno 11002] getaddrinfo failed)"))
# ❌ Exception for address 628 JURONG WEST ST 65: HTTPSConnectionPool(host='developers.onemap.sg', port=443): Max retries exceeded with url: /commonapi/search?searchVal=628+JURONG+WEST+ST+65&returnGeom=Y&getAddrDetails=Y&pageNum=1 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000020551CDD450>: Failed to resolve 'developers.onemap.sg' ([Errno 11002] getaddrinfo failed)"))
# ❌ Exception for address 5 HAIG RD: HTTPSConnectionPool(host='developers.onemap.sg', port=443): Max retries exceeded with url: /commonapi/search?searchVal=5+HAIG+RD&returnGeom=Y&getAddrDetails=Y&pageNum=1 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000020551CDE2F0>: Failed to resolve 'developers.onemap.sg' ([Errno 11002] getaddrinfo failed)"))
# ❌ Exception for address 206A COMPASSVALE LANE: HTTPSConnectionPool(host='developers.onemap.sg', port=443): Max retries exceeded with url: /commonapi/search?searchVal=206A+COMPASSVALE+LANE&returnGeom=Y&getAddrDetails=Y&pageNum=1 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x00000205521F0970>: Failed to resolve 'developers.onemap.sg' ([Errno 11002] getaddrinfo failed)"))
# ❌ Exception for address 143 LOR 2 TOA PAYOH: HTTPSConnectionPool(host='developers.onemap.sg', port=443): Max retries exceeded with url: /commonapi/search?searchVal=143+LOR+2+TOA+PAYOH&returnGeom=Y&getAddrDetails=Y&pageNum=1 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000020551CDEAA0>: Failed to resolve 'developers.onemap.sg' ([Errno 11002] getaddrinfo failed)"))
# ❌ Exception for address 329 CLEMENTI AVE 2: HTTPSConnectionPool(host='developers.onemap.sg', port=443): Max retries exceeded with url: /commonapi/search?searchVal=329+CLEMENTI+AVE+2&returnGeom=Y&getAddrDetails=Y&pageNum=1 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000020551CDD870>: Failed to resolve 'developers.onemap.sg' ([Errno 11002] getaddrinfo failed)"))
# ❌ Exception for address 431B YISHUN AVE 1: HTTPSConnectionPool(host='developers.onemap.sg', port=443): Max retries exceeded with url: /commonapi/search?searchVal=431B+YISHUN+AVE+1&returnGeom=Y&getAddrDetails=Y&pageNum=1 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000020551CDD540>: Failed to resolve 'developers.onemap.sg' ([Errno 11002] getaddrinfo failed)"))
# ❌ Exception for address 135 LOR AH SOO: HTTPSConnectionPool(host='developers.onemap.sg', port=443): Max retries exceeded with url: /commonapi/search?searchVal=135+LOR+AH+SOO&returnGeom=Y&getAddrDetails=Y&pageNum=1 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000020551CDF7F0>: Failed to resolve 'developers.onemap.sg' ([Errno 11002] getaddrinfo failed)"))
# ❌ Exception for address 185B RIVERVALE CRES: HTTPSConnectionPool(host='developers.onemap.sg', port=443): Max retries exceeded with url: /commonapi/search?searchVal=185B+RIVERVALE+CRES&returnGeom=Y&getAddrDetails=Y&pageNum=1 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000020552165330>: Failed to resolve 'developers.onemap.sg' ([Errno 11002] getaddrinfo failed)"))
# ❌ Exception for address 1 TELOK BLANGAH CRES: HTTPSConnectionPool(host='developers.onemap.sg', port=443): Max retries exceeded with url: /commonapi/search?searchVal=1+TELOK+BLANGAH+CRES&returnGeom=Y&getAddrDetails=Y&pageNum=1 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x00000205521F1060>: Failed to resolve 'developers.onemap.sg' ([Errno 11002] getaddrinfo failed)"))
# ❌ Exception for address 851 YISHUN ST 81: HTTPSConnectionPool(host='developers.onemap.sg', port=443): Max retries exceeded with url: /commonapi/search?searchVal=851+YISHUN+ST+81&returnGeom=Y&getAddrDetails=Y&pageNum=1 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000020551CDFD00>: Failed to resolve 'developers.onemap.sg' ([Errno 11002] getaddrinfo failed)"))
# ❌ Exception for address 552 ANG MO KIO AVE 10: HTTPSConnectionPool(host='developers.onemap.sg', port=443): Max retries exceeded with url: /commonapi/search?searchVal=552+ANG+MO+KIO+AVE+10&returnGeom=Y&getAddrDetails=Y&pageNum=1 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000020551CDFA30>: Failed to resolve 'developers.onemap.sg' ([Errno 11002] getaddrinfo failed)"))
# ❌ Exception for address 13 DOVER CL EAST: HTTPSConnectionPool(host='developers.onemap.sg', port=443): Max retries exceeded with url: /commonapi/search?searchVal=13+DOVER+CL+EAST&returnGeom=Y&getAddrDetails=Y&pageNum=1 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000020551CDDBD0>: Failed to resolve 'developers.onemap.sg' ([Errno 11002] getaddrinfo failed)"))
# ❌ Exception for address 686B WOODLANDS DR 73: HTTPSConnectionPool(host='developers.onemap.sg', port=443): Max retries exceeded with url: /commonapi/search?searchVal=686B+WOODLANDS+DR+73&returnGeom=Y&getAddrDetails=Y&pageNum=1 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000020551CDE7D0>: Failed to resolve 'developers.onemap.sg' ([Errno 11002] getaddrinfo failed)"))
# ❌ Exception for address 20 QUEEN'S CL: HTTPSConnectionPool(host='developers.onemap.sg', port=443): Max retries exceeded with url: /commonapi/search?searchVal=20+QUEEN%27S+CL&returnGeom=Y&getAddrDetails=Y&pageNum=1 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x00000205521F0C40>: Failed to resolve 'developers.onemap.sg' ([Errno 11002] getaddrinfo failed)"))
# ❌ Exception for address 104 JURONG EAST ST 13: HTTPSConnectionPool(host='developers.onemap.sg', port=443): Max retries exceeded with url: /commonapi/search?searchVal=104+JURONG+EAST+ST+13&returnGeom=Y&getAddrDetails=Y&pageNum=1 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000020552167F10>: Failed to resolve 'developers.onemap.sg' ([Errno 11002] getaddrinfo failed)"))
# ❌ Exception for address 832 HOUGANG CTRL: HTTPSConnectionPool(host='developers.onemap.sg', port=443): Max retries exceeded with url: /commonapi/search?searchVal=832+HOUGANG+CTRL&returnGeom=Y&getAddrDetails=Y&pageNum=1 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000020551CDE7A0>: Failed to resolve 'developers.onemap.sg' ([Errno 11002] getaddrinfo failed)"))
# ❌ Exception for address 523 BEDOK NTH ST 3: HTTPSConnectionPool(host='developers.onemap.sg', port=443): Max retries exceeded with url: /commonapi/search?searchVal=523+BEDOK+NTH+ST+3&returnGeom=Y&getAddrDetails=Y&pageNum=1 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000020551CDD450>: Failed to resolve 'developers.onemap.sg' ([Errno 11002] getaddrinfo failed)"))
# ❌ Exception for address 117 CLEMENTI ST 13: HTTPSConnectionPool(host='developers.onemap.sg', port=443): Max retries exceeded with url: /commonapi/search?searchVal=117+CLEMENTI+ST+13&returnGeom=Y&getAddrDetails=Y&pageNum=1 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000020551CDF6A0>: Failed to resolve 'developers.onemap.sg' ([Errno 11002] getaddrinfo failed)"))
# ❌ Exception for address 62A STRATHMORE AVE: HTTPSConnectionPool(host='developers.onemap.sg', port=443): Max retries exceeded with url: /commonapi/search?searchVal=62A+STRATHMORE+AVE&returnGeom=Y&getAddrDetails=Y&pageNum=1 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000020551CDF9A0>: Failed to resolve 'developers.onemap.sg' ([Errno 11002] getaddrinfo failed)"))
# ❌ Exception for address 58 DAKOTA CRES: HTTPSConnectionPool(host='developers.onemap.sg', port=443): Max retries exceeded with url: /commonapi/search?searchVal=58+DAKOTA+CRES&returnGeom=Y&getAddrDetails=Y&pageNum=1 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000020551CDE500>: Failed to resolve 'developers.onemap.sg' ([Errno 11002] getaddrinfo failed)"))
# ❌ Exception for address 338 TAMPINES ST 33: HTTPSConnectionPool(host='developers.onemap.sg', port=443): Max retries exceeded with url: /commonapi/search?searchVal=338+TAMPINES+ST+33&returnGeom=Y&getAddrDetails=Y&pageNum=1 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000020551CDDCF0>: Failed to resolve 'developers.onemap.sg' ([Errno 11002] getaddrinfo failed)"))
# ❌ Exception for address 526 BEDOK NTH ST 3: HTTPSConnectionPool(host='developers.onemap.sg', port=443): Max retries exceeded with url: /commonapi/search?searchVal=526+BEDOK+NTH+ST+3&returnGeom=Y&getAddrDetails=Y&pageNum=1 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000020551CDE260>: Failed to resolve 'developers.onemap.sg' ([Errno 11002] getaddrinfo failed)"))
# ❌ Exception for address 259 ANG MO KIO AVE 2: HTTPSConnectionPool(host='developers.onemap.sg', port=443): Max retries exceeded with url: /commonapi/search?searchVal=259+ANG+MO+KIO+AVE+2&returnGeom=Y&getAddrDetails=Y&pageNum=1 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000020551CDF640>: Failed to resolve 'developers.onemap.sg' ([Errno 11002] getaddrinfo failed)"))
# ❌ Exception for address 612C PUNGGOL DR: HTTPSConnectionPool(host='developers.onemap.sg', port=443): Max retries exceeded with url: /commonapi/search?searchVal=612C+PUNGGOL+DR&returnGeom=Y&getAddrDetails=Y&pageNum=1 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000020551CDCEB0>: Failed to resolve 'developers.onemap.sg' ([Errno 11002] getaddrinfo failed)"))
# ❌ Exception for address 254 BT BATOK EAST AVE 4: HTTPSConnectionPool(host='developers.onemap.sg', port=443): Max retries exceeded with url: /commonapi/search?searchVal=254+BT+BATOK+EAST+AVE+4&returnGeom=Y&getAddrDetails=Y&pageNum=1 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000020551CDD2A0>: Failed to resolve 'developers.onemap.sg' ([Errno 11002] getaddrinfo failed)"))
# ❌ Exception for address 472 SEGAR RD: HTTPSConnectionPool(host='developers.onemap.sg', port=443): Max retries exceeded with url: /commonapi/search?searchVal=472+SEGAR+RD&returnGeom=Y&getAddrDetails=Y&pageNum=1 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000020551CDE9E0>: Failed to resolve 'developers.onemap.sg' ([Errno 11002] getaddrinfo failed)"))
# ❌ Exception for address 2 DELTA AVE: HTTPSConnectionPool(host='developers.onemap.sg', port=443): Max retries exceeded with url: /commonapi/search?searchVal=2+DELTA+AVE&returnGeom=Y&getAddrDetails=Y&pageNum=1 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000020551CDF010>: Failed to resolve 'developers.onemap.sg' ([Errno 11002] getaddrinfo failed)"))
# ❌ Exception for address 454 HOUGANG AVE 10: HTTPSConnectionPool(host='developers.onemap.sg', port=443): Max retries exceeded with url: /commonapi/search?searchVal=454+HOUGANG+AVE+10&returnGeom=Y&getAddrDetails=Y&pageNum=1 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000020551CDE830>: Failed to resolve 'developers.onemap.sg' ([Errno 11002] getaddrinfo failed)"))
# ❌ Exception for address 215 ANG MO KIO AVE 1: HTTPSConnectionPool(host='developers.onemap.sg', port=443): Max retries exceeded with url: /commonapi/search?searchVal=215+ANG+MO+KIO+AVE+1&returnGeom=Y&getAddrDetails=Y&pageNum=1 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000020551CDD3F0>: Failed to resolve 'developers.onemap.sg' ([Errno 11002] getaddrinfo failed)"))
# ❌ Exception for address 835 YISHUN ST 81: HTTPSConnectionPool(host='developers.onemap.sg', port=443): Max retries exceeded with url: /commonapi/search?searchVal=835+YISHUN+ST+81&returnGeom=Y&getAddrDetails=Y&pageNum=1 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000020551CDFBE0>: Failed to resolve 'developers.onemap.sg' ([Errno 11002] getaddrinfo failed)"))
# ❌ Exception for address 360 BT BATOK ST 31: HTTPSConnectionPool(host='developers.onemap.sg', port=443): Max retries exceeded with url: /commonapi/search?searchVal=360+BT+BATOK+ST+31&returnGeom=Y&getAddrDetails=Y&pageNum=1 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000020551CDFEB0>: Failed to resolve 'developers.onemap.sg' ([Errno 11002] getaddrinfo failed)"))
# ❌ Exception for address 105 WOODLANDS ST 13: HTTPSConnectionPool(host='developers.onemap.sg', port=443): Max retries exceeded with url: /commonapi/search?searchVal=105+WOODLANDS+ST+13&returnGeom=Y&getAddrDetails=Y&pageNum=1 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000020552167EE0>: Failed to resolve 'developers.onemap.sg' ([Errno 11002] getaddrinfo failed)"))
# ❌ Exception for address 418 ANG MO KIO AVE 10: HTTPSConnectionPool(host='developers.onemap.sg', port=443): Max retries exceeded with url: /commonapi/search?searchVal=418+ANG+MO+KIO+AVE+10&returnGeom=Y&getAddrDetails=Y&pageNum=1 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000020551CDE890>: Failed to resolve 'developers.onemap.sg' ([Errno 11002] getaddrinfo failed)"))
# ❌ Exception for address 276 TOH GUAN RD: HTTPSConnectionPool(host='developers.onemap.sg', port=443): Max retries exceeded with url: /commonapi/search?searchVal=276+TOH+GUAN+RD&returnGeom=Y&getAddrDetails=Y&pageNum=1 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000020551CDE3E0>: Failed to resolve 'developers.onemap.sg' ([Errno 11002] getaddrinfo failed)"))
# ❌ Exception for address 114 HO CHING RD: HTTPSConnectionPool(host='developers.onemap.sg', port=443): Max retries exceeded with url: /commonapi/search?searchVal=114+HO+CHING+RD&returnGeom=Y&getAddrDetails=Y&pageNum=1 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000020551CDD540>: Failed to resolve 'developers.onemap.sg' ([Errno 11002] getaddrinfo failed)"))
# ❌ Exception for address 435B FERNVALE RD: HTTPSConnectionPool(host='developers.onemap.sg', port=443): Max retries exceeded with url: /commonapi/search?searchVal=435B+FERNVALE+RD&returnGeom=Y&getAddrDetails=Y&pageNum=1 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000020551CDD900>: Failed to resolve 'developers.onemap.sg' ([Errno 11002] getaddrinfo failed)"))
# ❌ Exception for address 786E WOODLANDS DR 60: HTTPSConnectionPool(host='developers.onemap.sg', port=443): Max retries exceeded with url: /commonapi/search?searchVal=786E+WOODLANDS+DR+60&returnGeom=Y&getAddrDetails=Y&pageNum=1 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x00000205521F1390>: Failed to resolve 'developers.onemap.sg' ([Errno 11002] getaddrinfo failed)"))
# ❌ Exception for address 897C WOODLANDS DR 50: HTTPSConnectionPool(host='developers.onemap.sg', port=443): Max retries exceeded with url: /commonapi/search?searchVal=897C+WOODLANDS+DR+50&returnGeom=Y&getAddrDetails=Y&pageNum=1 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000020551CDEBC0>: Failed to resolve 'developers.onemap.sg' ([Errno 11002] getaddrinfo failed)"))
# ❌ Exception for address 189 BT BATOK WEST AVE 6: HTTPSConnectionPool(host='developers.onemap.sg', port=443): Max retries exceeded with url: /commonapi/search?searchVal=189+BT+BATOK+WEST+AVE+6&returnGeom=Y&getAddrDetails=Y&pageNum=1 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000020551CDD270>: Failed to resolve 'developers.onemap.sg' ([Errno 11002] getaddrinfo failed)"))
# ❌ Exception for address 15 ST. GEORGE'S RD: HTTPSConnectionPool(host='developers.onemap.sg', port=443): Max retries exceeded with url: /commonapi/search?searchVal=15+ST.+GEORGE%27S+RD&returnGeom=Y&getAddrDetails=Y&pageNum=1 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000020551CDD930>: Failed to resolve 'developers.onemap.sg' ([Errno 11002] getaddrinfo failed)"))
# ❌ Exception for address 436D FERNVALE RD: HTTPSConnectionPool(host='developers.onemap.sg', port=443): Max retries exceeded with url: /commonapi/search?searchVal=436D+FERNVALE+RD&returnGeom=Y&getAddrDetails=Y&pageNum=1 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000020551CDD390>: Failed to resolve 'developers.onemap.sg' ([Errno 11002] getaddrinfo failed)"))
# ❌ Exception for address 501D WELLINGTON CIRCLE: HTTPSConnectionPool(host='developers.onemap.sg', port=443): Max retries exceeded with url: /commonapi/search?searchVal=501D+WELLINGTON+CIRCLE&returnGeom=Y&getAddrDetails=Y&pageNum=1 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000020551CDD840>: Failed to resolve 'developers.onemap.sg' ([Errno 11002] getaddrinfo failed)"))
# ❌ Exception for address 267 BT BATOK EAST AVE 4: HTTPSConnectionPool(host='developers.onemap.sg', port=443): Max retries exceeded with url: /commonapi/search?searchVal=267+BT+BATOK+EAST+AVE+4&returnGeom=Y&getAddrDetails=Y&pageNum=1 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000002054DFF40A0>: Failed to resolve 'developers.onemap.sg' ([Errno 11002] getaddrinfo failed)"))
# ❌ Exception for address 714 JURONG WEST ST 71: HTTPSConnectionPool(host='developers.onemap.sg', port=443): Max retries exceeded with url: /commonapi/search?searchVal=714+JURONG+WEST+ST+71&returnGeom=Y&getAddrDetails=Y&pageNum=1 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000020551CDEFB0>: Failed to resolve 'developers.onemap.sg' ([Errno 11002] getaddrinfo failed)"))
# ❌ Exception for address 862 TAMPINES ST 83: HTTPSConnectionPool(host='developers.onemap.sg', port=443): Max retries exceeded with url: /commonapi/search?searchVal=862+TAMPINES+ST+83&returnGeom=Y&getAddrDetails=Y&pageNum=1 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000020551CDE770>: Failed to resolve 'developers.onemap.sg' ([Errno 11002] getaddrinfo failed)"))
# ❌ Exception for address 415 ANG MO KIO AVE 10: HTTPSConnectionPool(host='developers.onemap.sg', port=443): Max retries exceeded with url: /commonapi/search?searchVal=415+ANG+MO+KIO+AVE+10&returnGeom=Y&getAddrDetails=Y&pageNum=1 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000020551CDF730>: Failed to resolve 'developers.onemap.sg' ([Errno 11002] getaddrinfo failed)"))
# ❌ Exception for address 66 BEDOK STH AVE 3: HTTPSConnectionPool(host='developers.onemap.sg', port=443): Max retries exceeded with url: /commonapi/search?searchVal=66+BEDOK+STH+AVE+3&returnGeom=Y&getAddrDetails=Y&pageNum=1 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000020551CDFCD0>: Failed to resolve 'developers.onemap.sg' ([Errno 11002] getaddrinfo failed)"))
# ❌ Exception for address 577 ANG MO KIO AVE 10: HTTPSConnectionPool(host='developers.onemap.sg', port=443): Max retries exceeded with url: /commonapi/search?searchVal=577+ANG+MO+KIO+AVE+10&returnGeom=Y&getAddrDetails=Y&pageNum=1 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000020551CDF6A0>: Failed to resolve 'developers.onemap.sg' ([Errno 11002] getaddrinfo failed)"))
# ❌ Exception for address 561 PASIR RIS ST 51: HTTPSConnectionPool(host='developers.onemap.sg', port=443): Max retries exceeded with url: /commonapi/search?searchVal=561+PASIR+RIS+ST+51&returnGeom=Y&getAddrDetails=Y&pageNum=1 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000020551D0DB10>: Failed to resolve 'developers.onemap.sg' ([Errno 11002] getaddrinfo failed)"))
# ❌ Exception for address 167D PUNGGOL EAST: HTTPSConnectionPool(host='developers.onemap.sg', port=443): Max retries exceeded with url: /commonapi/search?searchVal=167D+PUNGGOL+EAST&returnGeom=Y&getAddrDetails=Y&pageNum=1 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000020551CDCFD0>: Failed to resolve 'developers.onemap.sg' ([Errno 11002] getaddrinfo failed)"))
# ❌ Exception for address 617A PUNGGOL DR: HTTPSConnectionPool(host='developers.onemap.sg', port=443): Max retries exceeded with url: /commonapi/search?searchVal=617A+PUNGGOL+DR&returnGeom=Y&getAddrDetails=Y&pageNum=1 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000020551CDF820>: Failed to resolve 'developers.onemap.sg' ([Errno 11002] getaddrinfo failed)"))
# ❌ Exception for address 157 MEI LING ST: HTTPSConnectionPool(host='developers.onemap.sg', port=443): Max retries exceeded with url: /commonapi/search?searchVal=157+MEI+LING+ST&returnGeom=Y&getAddrDetails=Y&pageNum=1 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000020551CDE3E0>: Failed to resolve 'developers.onemap.sg' ([Errno 11002] getaddrinfo failed)"))
# ❌ Exception for address 272 BT BATOK EAST AVE 4: HTTPSConnectionPool(host='developers.onemap.sg', port=443): Max retries exceeded with url: /commonapi/search?searchVal=272+BT+BATOK+EAST+AVE+4&returnGeom=Y&getAddrDetails=Y&pageNum=1 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000020551CDEA40>: Failed to resolve 'developers.onemap.sg' ([Errno 11002] getaddrinfo failed)"))
# ❌ Exception for address 201E TAMPINES ST 23: HTTPSConnectionPool(host='developers.onemap.sg', port=443): Max retries exceeded with url: /commonapi/search?searchVal=201E+TAMPINES+ST+23&returnGeom=Y&getAddrDetails=Y&pageNum=1 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x00000205521F1570>: Failed to resolve 'developers.onemap.sg' ([Errno 11002] getaddrinfo failed)"))
# ❌ Exception for address 10 MARSILING DR: HTTPSConnectionPool(host='developers.onemap.sg', port=443): Max retries exceeded with url: /commonapi/search?searchVal=10+MARSILING+DR&returnGeom=Y&getAddrDetails=Y&pageNum=1 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000020551CDF250>: Failed to resolve 'developers.onemap.sg' ([Errno 11002] getaddrinfo failed)"))
# ❌ Exception for address 518 WOODLANDS DR 14: HTTPSConnectionPool(host='developers.onemap.sg', port=443): Max retries exceeded with url: /commonapi/search?searchVal=518+WOODLANDS+DR+14&returnGeom=Y&getAddrDetails=Y&pageNum=1 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000020551CDEA40>: Failed to resolve 'developers.onemap.sg' ([Errno 11002] getaddrinfo failed)"))
# ❌ Exception for address 146 SERANGOON NTH AVE 1: HTTPSConnectionPool(host='developers.onemap.sg', port=443): Max retries exceeded with url: /commonapi/search?searchVal=146+SERANGOON+NTH+AVE+1&returnGeom=Y&getAddrDetails=Y&pageNum=1 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000020551CDF970>: Failed to resolve 'developers.onemap.sg' ([Errno 11002] getaddrinfo failed)"))
# ❌ Exception for address 5A MARSILING DR: HTTPSConnectionPool(host='developers.onemap.sg', port=443): Max retries exceeded with url: /commonapi/search?searchVal=5A+MARSILING+DR&returnGeom=Y&getAddrDetails=Y&pageNum=1 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000020551CDD000>: Failed to resolve 'developers.onemap.sg' ([Errno 11002] getaddrinfo failed)"))
# ❌ Exception for address 339D KANG CHING RD: HTTPSConnectionPool(host='developers.onemap.sg', port=443): Max retries exceeded with url: /commonapi/search?searchVal=339D+KANG+CHING+RD&returnGeom=Y&getAddrDetails=Y&pageNum=1 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000020551CDFA00>: Failed to resolve 'developers.onemap.sg' ([Errno 11002] getaddrinfo failed)"))
# ❌ Exception for address 4 HOLLAND CL: HTTPSConnectionPool(host='developers.onemap.sg', port=443): Max retries exceeded with url: /commonapi/search?searchVal=4+HOLLAND+CL&returnGeom=Y&getAddrDetails=Y&pageNum=1 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000020551CDF2B0>: Failed to resolve 'developers.onemap.sg' ([Errno 11002] getaddrinfo failed)"))
# ❌ Exception for address 847 TAMPINES ST 83: HTTPSConnectionPool(host='developers.onemap.sg', port=443): Max retries exceeded with url: /commonapi/search?searchVal=847+TAMPINES+ST+83&returnGeom=Y&getAddrDetails=Y&pageNum=1 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000020551CDFA60>: Failed to resolve 'developers.onemap.sg' ([Errno 11002] getaddrinfo failed)"))
# ❌ Exception for address 618 ANG MO KIO AVE 4: HTTPSConnectionPool(host='developers.onemap.sg', port=443): Max retries exceeded with url: /commonapi/search?searchVal=618+ANG+MO+KIO+AVE+4&returnGeom=Y&getAddrDetails=Y&pageNum=1 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000020551CDF370>: Failed to resolve 'developers.onemap.sg' ([Errno 11002] getaddrinfo failed)"))
# ❌ Exception for address 114 HOUGANG AVE 1: HTTPSConnectionPool(host='developers.onemap.sg', port=443): Max retries exceeded with url: /commonapi/search?searchVal=114+HOUGANG+AVE+1&returnGeom=Y&getAddrDetails=Y&pageNum=1 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000020551CDD0F0>: Failed to resolve 'developers.onemap.sg' ([Errno 11002] getaddrinfo failed)"))
# ❌ Exception for address 425 BEDOK NTH RD: HTTPSConnectionPool(host='developers.onemap.sg', port=443): Max retries exceeded with url: /commonapi/search?searchVal=425+BEDOK+NTH+RD&returnGeom=Y&getAddrDetails=Y&pageNum=1 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000020551CDE3E0>: Failed to resolve 'developers.onemap.sg' ([Errno 11002] getaddrinfo failed)"))
# ❌ Exception for address 274D PUNGGOL PL: HTTPSConnectionPool(host='developers.onemap.sg', port=443): Max retries exceeded with url: /commonapi/search?searchVal=274D+PUNGGOL+PL&returnGeom=Y&getAddrDetails=Y&pageNum=1 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000020551CDEB60>: Failed to resolve 'developers.onemap.sg' ([Errno 11002] getaddrinfo failed)"))
# ❌ Exception for address 450F TAMPINES ST 42: HTTPSConnectionPool(host='developers.onemap.sg', port=443): Max retries exceeded with url: /commonapi/search?searchVal=450F+TAMPINES+ST+42&returnGeom=Y&getAddrDetails=Y&pageNum=1 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000020552167F70>: Failed to resolve 'developers.onemap.sg' ([Errno 11002] getaddrinfo failed)"))
# ❌ Exception for address 274 YISHUN ST 22: HTTPSConnectionPool(host='developers.onemap.sg', port=443): Max retries exceeded with url: /commonapi/search?searchVal=274+YISHUN+ST+22&returnGeom=Y&getAddrDetails=Y&pageNum=1 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000020551CDF940>: Failed to resolve 'developers.onemap.sg' ([Errno 11002] getaddrinfo failed)"))
# ❌ Exception for address 653C JURONG WEST ST 61: HTTPSConnectionPool(host='developers.onemap.sg', port=443): Max retries exceeded with url: /commonapi/search?searchVal=653C+JURONG+WEST+ST+61&returnGeom=Y&getAddrDetails=Y&pageNum=1 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000020551CDDAE0>: Failed to resolve 'developers.onemap.sg' ([Errno 11002] getaddrinfo failed)"))
# ❌ Exception for address 80A TELOK BLANGAH ST 31: HTTPSConnectionPool(host='developers.onemap.sg', port=443): Max retries exceeded with url: /commonapi/search?searchVal=80A+TELOK+BLANGAH+ST+31&returnGeom=Y&getAddrDetails=Y&pageNum=1 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000020551CDD420>: Failed to resolve 'developers.onemap.sg' ([Errno 11002] getaddrinfo failed)"))
# ❌ Exception for address 508 BT BATOK ST 52: HTTPSConnectionPool(host='developers.onemap.sg', port=443): Max retries exceeded with url: /commonapi/search?searchVal=508+BT+BATOK+ST+52&returnGeom=Y&getAddrDetails=Y&pageNum=1 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000020551CDE050>: Failed to resolve 'developers.onemap.sg' ([Errno 11002] getaddrinfo failed)"))
# ...
# ❌ Exception for address 671B KLANG LANE: HTTPSConnectionPool(host='developers.onemap.sg', port=443): Max retries exceeded with url: /commonapi/search?searchVal=671B+KLANG+LANE&returnGeom=Y&getAddrDetails=Y&pageNum=1 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000002054BC69BD0>: Failed to resolve 'developers.onemap.sg' ([Errno 11002] getaddrinfo failed)"))
# ❌ Exception for address 119A RIVERVALE DR: HTTPSConnectionPool(host='developers.onemap.sg', port=443): Max retries exceeded with url: /commonapi/search?searchVal=119A+RIVERVALE+DR&returnGeom=Y&getAddrDetails=Y&pageNum=1 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000002054B36E110>: Failed to resolve 'developers.onemap.sg' ([Errno 11002] getaddrinfo failed)"))
# ❌ Exception for address 834 WOODLANDS ST 83: HTTPSConnectionPool(host='developers.onemap.sg', port=443): Max retries exceeded with url: /commonapi/search?searchVal=834+WOODLANDS+ST+83&returnGeom=Y&getAddrDetails=Y&pageNum=1 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000020551CDDDB0>: Failed to resolve 'developers.onemap.sg' ([Errno 11002] getaddrinfo failed)"))
# ❌ Exception for address 36 TEBAN GDNS RD: HTTPSConnectionPool(host='developers.onemap.sg', port=443): Max retries exceeded with url: /commonapi/search?searchVal=36+TEBAN+GDNS+RD&returnGeom=Y&getAddrDetails=Y&pageNum=1 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000020551CDF5E0>: Failed to resolve 'developers.onemap.sg' ([Errno 11002] getaddrinfo failed)"))
# ❌ Exception for address 418 HOUGANG AVE 8: HTTPSConnectionPool(host='developers.onemap.sg', port=443): Max retries exceeded with url: /commonapi/search?searchVal=418+HOUGANG+AVE+8&returnGeom=Y&getAddrDetails=Y&pageNum=1 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000020551CDD210>: Failed to resolve 'developers.onemap.sg' ([Errno 11002] getaddrinfo failed)"))
# ❌ Exception for address 446 YISHUN AVE 11: HTTPSConnectionPool(host='developers.onemap.sg', port=443): Max retries exceeded with url: /commonapi/search?searchVal=446+YISHUN+AVE+11&returnGeom=Y&getAddrDetails=Y&pageNum=1 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000020550BFD3C0>: Failed to resolve 'developers.onemap.sg' ([Errno 11002] getaddrinfo failed)"))
# ❌ Exception for address 226 CHOA CHU KANG CTRL: HTTPSConnectionPool(host='developers.onemap.sg', port=443): Max retries exceeded with url: /commonapi/search?searchVal=226+CHOA+CHU+KANG+CTRL&returnGeom=Y&getAddrDetails=Y&pageNum=1 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000020552167FD0>: Failed to resolve 'developers.onemap.sg' ([Errno 11002] getaddrinfo failed)"))
# ❌ Exception for address 720 YISHUN ST 71: HTTPSConnectionPool(host='developers.onemap.sg', port=443): Max retries exceeded with url: /commonapi/search?searchVal=720+YISHUN+ST+71&returnGeom=Y&getAddrDetails=Y&pageNum=1 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000020551CDE560>: Failed to resolve 'developers.onemap.sg' ([Errno 11002] getaddrinfo failed)"))
# ❌ Exception for address 45 TELOK BLANGAH DR: HTTPSConnectionPool(host='developers.onemap.sg', port=443): Max retries exceeded with url: /commonapi/search?searchVal=45+TELOK+BLANGAH+DR&returnGeom=Y&getAddrDetails=Y&pageNum=1 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000020551CDE6E0>: Failed to resolve 'developers.onemap.sg' ([Errno 11002] getaddrinfo failed)"))
# ❌ Exception for address 406 SIN MING AVE: HTTPSConnectionPool(host='developers.onemap.sg', port=443): Max retries exceeded with url: /commonapi/search?searchVal=406+SIN+MING+AVE&returnGeom=Y&getAddrDetails=Y&pageNum=1 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000020551CDFAF0>: Failed to resolve 'developers.onemap.sg' ([Errno 11002] getaddrinfo failed)"))
# ❌ Exception for address 103 ANG MO KIO AVE 3: HTTPSConnectionPool(host='developers.onemap.sg', port=443): Max retries exceeded with url: /commonapi/search?searchVal=103+ANG+MO+KIO+AVE+3&returnGeom=Y&getAddrDetails=Y&pageNum=1 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000020550A7CFA0>: Failed to resolve 'developers.onemap.sg' ([Errno 11002] getaddrinfo failed)"))
# ❌ Exception for address 103 HOUGANG AVE 1: HTTPSConnectionPool(host='developers.onemap.sg', port=443): Max retries exceeded with url: /commonapi/search?searchVal=103+HOUGANG+AVE+1&returnGeom=Y&getAddrDetails=Y&pageNum=1 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000002054E046EF0>: Failed to resolve 'developers.onemap.sg' ([Errno 11002] getaddrinfo failed)"))
# ❌ Exception for address 111 EDGEFIELD PLAINS: HTTPSConnectionPool(host='developers.onemap.sg', port=443): Max retries exceeded with url: /commonapi/search?searchVal=111+EDGEFIELD+PLAINS&returnGeom=Y&getAddrDetails=Y&pageNum=1 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000020550BFD750>: Failed to resolve 'developers.onemap.sg' ([Errno 11002] getaddrinfo failed)"))
# ❌ Exception for address 637 YISHUN ST 61: HTTPSConnectionPool(host='developers.onemap.sg', port=443): Max retries exceeded with url: /commonapi/search?searchVal=637+YISHUN+ST+61&returnGeom=Y&getAddrDetails=Y&pageNum=1 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000020551CDEEF0>: Failed to resolve 'developers.onemap.sg' ([Errno 11002] getaddrinfo failed)"))
# ❌ Exception for address 5 BEDOK STH AVE 2: HTTPSConnectionPool(host='developers.onemap.sg', port=443): Max retries exceeded with url: /commonapi/search?searchVal=5+BEDOK+STH+AVE+2&returnGeom=Y&getAddrDetails=Y&pageNum=1 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000020551CDEC80>: Failed to resolve 'developers.onemap.sg' ([Errno 11002] getaddrinfo failed)"))
# ❌ Exception for address 422 CHOA CHU KANG AVE 4: HTTPSConnectionPool(host='developers.onemap.sg', port=443): Max retries exceeded with url: /commonapi/search?searchVal=422+CHOA+CHU+KANG+AVE+4&returnGeom=Y&getAddrDetails=Y&pageNum=1 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000020551CDE860>: Failed to resolve 'developers.onemap.sg' ([Errno 11002] getaddrinfo failed)"))
# ❌ Exception for address 34 MARINE CRES: HTTPSConnectionPool(host='developers.onemap.sg', port=443): Max retries exceeded with url: /commonapi/search?searchVal=34+MARINE+CRES&returnGeom=Y&getAddrDetails=Y&pageNum=1 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000020550BFD660>: Failed to resolve 'developers.onemap.sg' ([Errno 11002] getaddrinfo failed)"))
# ❌ Exception for address 451 CHOA CHU KANG AVE 4: HTTPSConnectionPool(host='developers.onemap.sg', port=443): Max retries exceeded with url: /commonapi/search?searchVal=451+CHOA+CHU+KANG+AVE+4&returnGeom=Y&getAddrDetails=Y&pageNum=1 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000020551D0DAB0>: Failed to resolve 'developers.onemap.sg' ([Errno 11002] getaddrinfo failed)"))
# ❌ Exception for address 59 STRATHMORE AVE: HTTPSConnectionPool(host='developers.onemap.sg', port=443): Max retries exceeded with url: /commonapi/search?searchVal=59+STRATHMORE+AVE&returnGeom=Y&getAddrDetails=Y&pageNum=1 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000020551CDF430>: Failed to resolve 'developers.onemap.sg' ([Errno 11002] getaddrinfo failed)"))
# ❌ Exception for address 112 JURONG EAST ST 13: HTTPSConnectionPool(host='developers.onemap.sg', port=443): Max retries exceeded with url: /commonapi/search?searchVal=112+JURONG+EAST+ST+13&returnGeom=Y&getAddrDetails=Y&pageNum=1 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000020551CDFBB0>: Failed to resolve 'developers.onemap.sg' ([Errno 11002] getaddrinfo failed)"))
# ❌ Exception for address 234 JURONG EAST ST 21: HTTPSConnectionPool(host='developers.onemap.sg', port=443): Max retries exceeded with url: /commonapi/search?searchVal=234+JURONG+EAST+ST+21&returnGeom=Y&getAddrDetails=Y&pageNum=1 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000020551CDD5D0>: Failed to resolve 'developers.onemap.sg' ([Errno 11002] getaddrinfo failed)"))
# ❌ Exception for address 80C TELOK BLANGAH ST 31: HTTPSConnectionPool(host='developers.onemap.sg', port=443): Max retries exceeded with url: /commonapi/search?searchVal=80C+TELOK+BLANGAH+ST+31&returnGeom=Y&getAddrDetails=Y&pageNum=1 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000020550A7CD30>: Failed to resolve 'developers.onemap.sg' ([Errno 11002] getaddrinfo failed)"))
# ❌ Exception for address 669B JURONG WEST ST 64: HTTPSConnectionPool(host='developers.onemap.sg', port=443): Max retries exceeded with url: /commonapi/search?searchVal=669B+JURONG+WEST+ST+64&returnGeom=Y&getAddrDetails=Y&pageNum=1 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000020550D48820>: Failed to resolve 'developers.onemap.sg' ([Errno 11002] getaddrinfo failed)"))
# ❌ Exception for address 41 TEBAN GDNS RD: HTTPSConnectionPool(host='developers.onemap.sg', port=443): Max retries exceeded with url: /commonapi/search?searchVal=41+TEBAN+GDNS+RD&returnGeom=Y&getAddrDetails=Y&pageNum=1 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000020551CDD540>: Failed to resolve 'developers.onemap.sg' ([Errno 11002] getaddrinfo failed)"))
# ❌ Exception for address 636 CHOA CHU KANG NTH 6: HTTPSConnectionPool(host='developers.onemap.sg', port=443): Max retries exceeded with url: /commonapi/search?searchVal=636+CHOA+CHU+KANG+NTH+6&returnGeom=Y&getAddrDetails=Y&pageNum=1 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000020551CDD690>: Failed to resolve 'developers.onemap.sg' ([Errno 11002] getaddrinfo failed)"))
# ❌ Exception for address 51 LOR 6 TOA PAYOH: HTTPSConnectionPool(host='developers.onemap.sg', port=443): Max retries exceeded with url: /commonapi/search?searchVal=51+LOR+6+TOA+PAYOH&returnGeom=Y&getAddrDetails=Y&pageNum=1 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000020551CDFE80>: Failed to resolve 'developers.onemap.sg' ([Errno 11002] getaddrinfo failed)"))
# ❌ Exception for address 6A BOON TIONG RD: HTTPSConnectionPool(host='developers.onemap.sg', port=443): Max retries exceeded with url: /commonapi/search?searchVal=6A+BOON+TIONG+RD&returnGeom=Y&getAddrDetails=Y&pageNum=1 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000020550A7CB50>: Failed to resolve 'developers.onemap.sg' ([Errno 11002] getaddrinfo failed)"))
# ❌ Exception for address 788D WOODLANDS CRES: HTTPSConnectionPool(host='developers.onemap.sg', port=443): Max retries exceeded with url: /commonapi/search?searchVal=788D+WOODLANDS+CRES&returnGeom=Y&getAddrDetails=Y&pageNum=1 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000020550BFD720>: Failed to resolve 'developers.onemap.sg' ([Errno 11002] getaddrinfo failed)"))
# ❌ Exception for address 283 TAMPINES ST 22: HTTPSConnectionPool(host='developers.onemap.sg', port=443): Max retries exceeded with url: /commonapi/search?searchVal=283+TAMPINES+ST+22&returnGeom=Y&getAddrDetails=Y&pageNum=1 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000020551CDD120>: Failed to resolve 'developers.onemap.sg' ([Errno 11002] getaddrinfo failed)"))
# ❌ Exception for address 121 POTONG PASIR AVE 1: HTTPSConnectionPool(host='developers.onemap.sg', port=443): Max retries exceeded with url: /commonapi/search?searchVal=121+POTONG+PASIR+AVE+1&returnGeom=Y&getAddrDetails=Y&pageNum=1 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000020551CDD840>: Failed to resolve 'developers.onemap.sg' ([Errno 11002] getaddrinfo failed)"))
# ❌ Exception for address 220 SERANGOON AVE 4: HTTPSConnectionPool(host='developers.onemap.sg', port=443): Max retries exceeded with url: /commonapi/search?searchVal=220+SERANGOON+AVE+4&returnGeom=Y&getAddrDetails=Y&pageNum=1 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000020551CDE1D0>: Failed to resolve 'developers.onemap.sg' ([Errno 11002] getaddrinfo failed)"))
# ❌ Exception for address 633D SENJA RD: HTTPSConnectionPool(host='developers.onemap.sg', port=443): Max retries exceeded with url: /commonapi/search?searchVal=633D+SENJA+RD&returnGeom=Y&getAddrDetails=Y&pageNum=1 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000020551D0F160>: Failed to resolve 'developers.onemap.sg' ([Errno 11002] getaddrinfo failed)"))
# ❌ Exception for address 12 KG ARANG RD: HTTPSConnectionPool(host='developers.onemap.sg', port=443): Max retries exceeded with url: /commonapi/search?searchVal=12+KG+ARANG+RD&returnGeom=Y&getAddrDetails=Y&pageNum=1 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000002054A3E5E10>: Failed to resolve 'developers.onemap.sg' ([Errno 11002] getaddrinfo failed)"))
# ❌ Exception for address 109 ANG MO KIO AVE 4: HTTPSConnectionPool(host='developers.onemap.sg', port=443): Max retries exceeded with url: /commonapi/search?searchVal=109+ANG+MO+KIO+AVE+4&returnGeom=Y&getAddrDetails=Y&pageNum=1 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000020551D0DB70>: Failed to resolve 'developers.onemap.sg' ([Errno 11002] getaddrinfo failed)"))
# ❌ Exception for address 401 ADMIRALTY LINK: HTTPSConnectionPool(host='developers.onemap.sg', port=443): Max retries exceeded with url: /commonapi/search?searchVal=401+ADMIRALTY+LINK&returnGeom=Y&getAddrDetails=Y&pageNum=1 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000020551CDE1D0>: Failed to resolve 'developers.onemap.sg' ([Errno 11002] getaddrinfo failed)"))
# ❌ Exception for address 887C WOODLANDS DR 50: HTTPSConnectionPool(host='developers.onemap.sg', port=443): Max retries exceeded with url: /commonapi/search?searchVal=887C+WOODLANDS+DR+50&returnGeom=Y&getAddrDetails=Y&pageNum=1 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000020551CDFB80>: Failed to resolve 'developers.onemap.sg' ([Errno 11002] getaddrinfo failed)"))
# ❌ Exception for address 339B SEMBAWANG CL: HTTPSConnectionPool(host='developers.onemap.sg', port=443): Max retries exceeded with url: /commonapi/search?searchVal=339B+SEMBAWANG+CL&returnGeom=Y&getAddrDetails=Y&pageNum=1 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000020551CDDD80>: Failed to resolve 'developers.onemap.sg' ([Errno 11002] getaddrinfo failed)"))
# ❌ Exception for address 552 PASIR RIS ST 51: HTTPSConnectionPool(host='developers.onemap.sg', port=443): Max retries exceeded with url: /commonapi/search?searchVal=552+PASIR+RIS+ST+51&returnGeom=Y&getAddrDetails=Y&pageNum=1 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000020550BFD8D0>: Failed to resolve 'developers.onemap.sg' ([Errno 11002] getaddrinfo failed)"))
# ❌ Exception for address 817 TAMPINES ST 81: HTTPSConnectionPool(host='developers.onemap.sg', port=443): Max retries exceeded with url: /commonapi/search?searchVal=817+TAMPINES+ST+81&returnGeom=Y&getAddrDetails=Y&pageNum=1 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000002054A3E5F00>: Failed to resolve 'developers.onemap.sg' ([Errno 11002] getaddrinfo failed)"))

# %%
[
  {'address': '216 ANG MO KIO AVE 1', 'latitude': '1.35591569798152', 'longitude': '103.844851266401'},
  {'address': '101 RIVERVALE WALK', 'latitude': '1.393245', 'longitude': '103.905671'},
  ...
]

# %%
geo_df = pd.DataFrame(query_results)

# %%
geo_df.to_csv("geocoded_addresses.csv", index=False)

# %%
pip install folium

# %% [markdown]
# Next, we write a simple script to execute batch geocoding, i.e. convert addresses to longitudes and latitudes.
#
# The script will loop through all addresses in ```test_address_list``` and convert it into a query form. Then it calls the OneMap API. The API provides searching of address data for a given search value. It returns search results with both latitude, longitude and x, y coordinates of the searched. Our script here returns a list of query results.

# %%
# %%time
import requests

query_results = []
querystring = {}

for x in full_address_list:
    url = "https://developers.onemap.sg/commonapi/search"
    

    querystring.update({"searchVal":x,"returnGeom":"Y","getAddrDetails":"Y","pageNum":"1"})
    #print (querystring['searchVal'])
    
    payload = "------WebKitFormBoundary7MA4YWxkTrZu0gW\r\nContent-Disposition: form-data; name=\"searchVal\"\r\n\r\n\r\n------WebKitFormBoundary7MA4YWxkTrZu0gW\r\nContent-Disposition: form-data; name=\"returnGeom {Y/N}\"\r\n\r\n\r\n------WebKitFormBoundary7MA4YWxkTrZu0gW\r\nContent-Disposition: form-data; name=\"getAddrDetails {Y/N}\"\r\n\r\n\r\n------WebKitFormBoundary7MA4YWxkTrZu0gW\r\nContent-Disposition: form-data; name=\"pageNum\"\r\n\r\n\r\n------WebKitFormBoundary7MA4YWxkTrZu0gW--"
    headers = {
    'content-type': "multipart/form-data; boundary=----WebKitFormBoundary7MA4YWxkTrZu0gW",
    'Cache-Control': "no-cache",
    'Postman-Token': "5f4af03e-410e-4b28-93bc-05006b4de49a"
    }

    response = requests.request("GET", url, data=payload, headers=headers, params=querystring)
    

    query_results.append(response.json())

#print(response.text)
print('Search Done.')
# Out:
# Search Done.
# Wall time: 3h 42min 2s

# %%
type(query_results)
# Out:
# list

# %%
len(query_results)
# Out:
# 8838

# %%
query_results[1]['results']
# Out:
# [{'ADDRESS': '211 ANG MO KIO AVENUE 3 HDB-ANG MO KIO SINGAPORE 560211',
#   'BLK_NO': '211',
#   'BUILDING': 'HDB-ANG MO KIO',
#   'LATITUDE': '1.36919696561704',
#   'LONGITUDE': '103.841666636086',
#   'LONGTITUDE': '103.841666636086',
#   'POSTAL': '560211',
#   'ROAD_NAME': 'ANG MO KIO AVENUE 3',
#   'SEARCHVAL': 'HDB-ANG MO KIO',
#   'X': '28929.0379298832',
#   'Y': '39024.3611866999'}]

# %%
type(query_results[1]['results'])
# Out:
# list

# %%
df1 = pd.DataFrame.from_dict(query_results[0]['results'])

# %% [markdown]
# We proceed to create a dataframe out of results retrieved from the API.

# %%
latlong_df = pd.DataFrame()
for entry in range(len(query_results)):
    temp_df = pd.DataFrame.from_dict(query_results[entry]['results'])
    latlong_df = latlong_df.append(temp_df)

# %%
latlong_df.head()
# Out:
#                                              ADDRESS BLK_NO  \
# 0  216 ANG MO KIO AVENUE 1 ANG MO KIO 22 SINGAPOR...    216
# 0  211 ANG MO KIO AVENUE 3 HDB-ANG MO KIO SINGAPO...    211
# 0  202 ANG MO KIO AVENUE 3 ANG MO KIO VIEW SINGAP...    202
# 1  202 ANG MO KIO AVENUE 3 OCBC Ang Mo Kio Ave 3 ...    202
# 0  235 ANG MO KIO AVENUE 3 KEBUN BARU PALM VIEW S...    235
#
#                 BUILDING          LATITUDE         LONGITUDE  \
# 0          ANG MO KIO 22  1.36619678831055  103.841505011903
# 0         HDB-ANG MO KIO  1.36919696561704  103.841666636086
# 0        ANG MO KIO VIEW   1.3684464401094  103.844516260527
# 1  OCBC Ang Mo Kio Ave 3  1.36845752328242  103.844515336938
# 0   KEBUN BARU PALM VIEW  1.36682360872345   103.83649123351
#
#          LONGTITUDE  POSTAL            ROAD_NAME              SEARCHVAL  \
# 0  103.841505011903  560216  ANG MO KIO AVENUE 1          ANG MO KIO 22
# 0  103.841666636086  560211  ANG MO KIO AVENUE 3         HDB-ANG MO KIO
# 0  103.844516260527  560202  ANG MO KIO AVENUE 3        ANG MO KIO VIEW
# 1  103.844515336938  560202  ANG MO KIO AVENUE 3  OCBC Ang Mo Kio Ave 3
# 0   103.83649123351  560235  ANG MO KIO AVENUE 3   KEBUN BARU PALM VIEW
#
#                   X                 Y
# 0  28911.0522399386   38692.616790574
# 0  28929.0379298832  39024.3611866999
# 0  29246.1670971224  38941.3731856439
# 1  29246.0643070498  38942.5987060368
# 0  28353.0784864295   38761.926084429

# %%
latlong_df.shape
# Out:
# (11784, 11)

# %%
latlong_df["full_address"] = latlong_df["BLK_NO"].map(str) + ' ' + latlong_df["ROAD_NAME"].map(str)

# %%
# Do the same for the dataset which contains HDB resale addresses
latlong_df["lat_long"] = latlong_df["LATITUDE"] +' '+ latlong_df["LONGITUDE"]
# convert lat_long column to tuples
latlong_df["lat_long"] = latlong_df["lat_long"].apply(lambda x: tuple(x.split(' ')))

# %%
# Save/load latlong_df
latlong_df.to_pickle('data/latlong_df.pkl')    
#latlong_df = pd.read_pickle('data/latlong_df.pkl')

# %% [markdown]
# ---

# %% [markdown]
# ## Distance to Nearest MRT Station Exit

# %% [markdown]
# Since we want to build a dashboard that allows users to input their budget and optimize the recommendation of flat types using a variety of considerations. These considerations can be something like, "With my budget, show me the the town that has largest flat type, and also one that is closest to a MRT station."
#
# The following code is on importing *MRT stations' Exits Address* and *Schools' Address* data, conducting geocoding through OneMap API, and calculating the distance of each address to the its nearest station.
#
# All distances are geodesic distances between two points, adapted from the Python's ```geopy``` package.

# %%
# shapefile to csv converter; 
# Thanks to https://gist.github.com/aerispaha/f098916ac041c286ae92d037ba5c37ba
def read_shapefile(shp_path):
    """
    Read a shapefile into a Pandas dataframe with a 'coords' column holding
    the geometry information. This uses the pyshp package
    """
    import shapefile

    myshp = open(shp_path, "rb")
    #read file, parse out the records and shapes
    sf = shapefile.Reader(shp_path)
    fields = [x[0] for x in sf.fields][1:]
    records = sf.records()
    shps = [s.points for s in sf.shapes()]

    #write into a dataframe
    df = pd.DataFrame(columns=fields, data=records)
    df = df.assign(coords=shps)

    return df

# %%
mrt_latlong_df = read_shapefile("data/MRTLRTStnPtt.shp")

# %%
station_address_list = mrt_latlong_df["STN_NAME"].unique().tolist()
len(station_address_list)
# Out:
# 164

# %% [markdown]
# This dataset contains address of 164 MRT stations' exits. So we proceed to get their corresponding longitude and latitude.

# %%
# %%time
import requests

station_search_results = []
querystring = {}

for x in station_address_list:
    url = "https://developers.onemap.sg/commonapi/search"
    

    querystring.update({"searchVal":x,"returnGeom":"Y","getAddrDetails":"Y","pageNum":"1"})
    #print (querystring['searchVal'])
    
    payload = "------WebKitFormBoundary7MA4YWxkTrZu0gW\r\nContent-Disposition: form-data; name=\"searchVal\"\r\n\r\n\r\n------WebKitFormBoundary7MA4YWxkTrZu0gW\r\nContent-Disposition: form-data; name=\"returnGeom {Y/N}\"\r\n\r\n\r\n------WebKitFormBoundary7MA4YWxkTrZu0gW\r\nContent-Disposition: form-data; name=\"getAddrDetails {Y/N}\"\r\n\r\n\r\n------WebKitFormBoundary7MA4YWxkTrZu0gW\r\nContent-Disposition: form-data; name=\"pageNum\"\r\n\r\n\r\n------WebKitFormBoundary7MA4YWxkTrZu0gW--"
    headers = {
    'content-type': "multipart/form-data; boundary=----WebKitFormBoundary7MA4YWxkTrZu0gW",
    'Cache-Control': "no-cache",
    'Postman-Token': "5f4af03e-410e-4b28-93bc-05006b4de49a"
    }

    response = requests.request("GET", url, data=payload, headers=headers, params=querystring)
    

    station_search_results.append(response.json())

#print(response.text)
print('Search Done.')
# Out:
# Search Done.
# Wall time: 4min 1s

# %%
station_latlong_df = pd.DataFrame()
for entry in range(len(station_search_results)):
    temp_df = pd.DataFrame.from_dict(station_search_results[entry]['results'])
    station_latlong_df = station_latlong_df.append(temp_df)

# %%
station_latlong_df.head(1)
# Out:
#                               ADDRESS BLK_NO                  BUILDING  \
# 0  EUNOS MRT STATION EXIT C SINGAPORE         EUNOS MRT STATION EXIT C
#
#            LATITUDE         LONGITUDE        LONGTITUDE POSTAL ROAD_NAME  \
# 0  1.31960866729867  103.903178612002  103.903178612002    NIL       NIL
#
#                   SEARCHVAL                 X                 Y
# 0  EUNOS MRT STATION EXIT C  35774.7365172636  33541.2481965665

# %%
# Concatenate latitude and longitude columns into one column
station_latlong_df["lat_long"] = station_latlong_df["LATITUDE"] +' '+ station_latlong_df["LONGITUDE"]

# convert lat_long column to tuples
station_latlong_df["lat_long"] = station_latlong_df["lat_long"].apply(lambda x: tuple(x.split(' ')))

# %%
station_latlong_df.reset_index()

# convert the lat_long column in station_latlong_df to a list
station_latlong_list = list(station_latlong_df.T.iloc[-1,:])

# %%
station_latlong_list[0:3]
# Out:
# [('1.31960866729867', '103.903178612002'),
#  ('1.31951727513527', '103.902894137829'),
#  ('1.31956254560617', '103.90258207739')]

# %% [markdown]
# ```station_latlong_list``` is a list of stations in tuples of latitude and longitude. We need it for each address to loop over each coordinate in the list, and caluculate the distance.

# %%
# %%time
station_distance_df = pd.DataFrame(latlong_df["lat_long"])
for x in station_latlong_list:
    station_distance_df[x]=latlong_df['lat_long'].apply(lambda y: geopy.distance.vincenty(y, x).km)
# Out:
# Wall time: 3min 9s

# %%
station_distance_df.shape
# Out:
# (11784, 492)

# %%
# get the distance from each address to the nearest station
station_distance_df['distance_to_nearest_station'] = station_distance_df.iloc[:,1:].apply(lambda x: min(x), axis=1)

# %%
station_distance_df = station_distance_df.iloc[:,[0,-1]]
station_distance_df.head(1)
# Out:
#                                lat_long  distance_to_nearest_station
# 0  (1.36619678831055, 103.841505011903)                     0.954205

# %% [markdown]
# Take a look at the last column, ```distance_to_nearest_station``` is the distance to the nearest MRT station's exit, measured in kilometres.

# %%
# Merge our results into the main hdb address dataframe: latlong_df
latlong_df_final = pd.merge(latlong_df, station_distance_df, on='lat_long', how='left')

# %% [markdown]
# ---

# %% [markdown]
# ## Distance to Nearest School

# %% [markdown]
# We repeat the above steps to get distance to nearest school.

# %%
school_address_df = pd.read_csv("data/general-information-of-schools.csv")

# %%
school_address_df
# Out:
#                                         school_name  \
# 0                           NATIONAL JUNIOR COLLEGE
# 1                            TEMASEK JUNIOR COLLEGE
# 2                             JURONG JUNIOR COLLEGE
# 3                           ANDERSON JUNIOR COLLEGE
# 4                           VICTORIA JUNIOR COLLEGE
# 5                             YISHUN JUNIOR COLLEGE
# 6                           TAMPINES JUNIOR COLLEGE
# 7                          SERANGOON JUNIOR COLLEGE
# 8                            PIONEER JUNIOR COLLEGE
# 9                           MERIDIAN JUNIOR COLLEGE
# 10                            INNOVA JUNIOR COLLEGE
# 11                            EUNOIA JUNIOR COLLEGE
# 12                          CATHOLIC JUNIOR COLLEGE
# 13                     ANGLO-CHINESE JUNIOR COLLEGE
# 14                      ST. ANDREW'S JUNIOR COLLEGE
# 15                           NANYANG JUNIOR COLLEGE
# 16                            HWA CHONG INSTITUTION
# 17                              MILLENNIA INSTITUTE
# 18                     BUKIT PANJANG PRIMARY SCHOOL
# 19                               HAIG GIRLS' SCHOOL
# 20                         TECK WHYE PRIMARY SCHOOL
# 21                            JURONG PRIMARY SCHOOL
# 22                        QUEENSTOWN PRIMARY SCHOOL
# 23                         RADIN MAS PRIMARY SCHOOL
# 24                    RAFFLES GIRLS' PRIMARY SCHOOL
# 25                                    ROSYTH SCHOOL
# 26                             DAMAI PRIMARY SCHOOL
# 27                             FUHUA PRIMARY SCHOOL
# 28                         WOODLANDS PRIMARY SCHOOL
# 29                             EUNOS PRIMARY SCHOOL
# ..                                              ...
# 328                  CHRIST CHURCH SECONDARY SCHOOL
# 329  PAYA LEBAR METHODIST GIRLS' SCHOOL (SECONDARY)
# 330                         YUYING SECONDARY SCHOOL
# 331         KUO CHUAN PRESBYTERIAN SECONDARY SCHOOL
# 332                    ST. HILDA'S SECONDARY SCHOOL
# 333             METHODIST GIRLS' SCHOOL (SECONDARY)
# 334                        HAI SING CATHOLIC SCHOOL
# 335              ANGLO-CHINESE SCHOOL (BARKER ROAD)
# 336                            ANGLICAN HIGH SCHOOL
# 337                            CATHOLIC HIGH SCHOOL
# 338                  CHUNG CHENG HIGH SCHOOL (MAIN)
# 339                CHUNG CHENG HIGH SCHOOL (YISHUN)
# 340                     HOLY INNOCENTS' HIGH SCHOOL
# 341                        MARIS STELLA HIGH SCHOOL
# 342                           NAN CHIAU HIGH SCHOOL
# 343                      NANYANG GIRLS' HIGH SCHOOL
# 344                 CHIJ ST. NICHOLAS GIRLS' SCHOOL
# 345                        MARYMOUNT CONVENT SCHOOL
# 346                       MANJUSRI SECONDARY SCHOOL
# 347                        PRESBYTERIAN HIGH SCHOOL
# 348          FAIRFIELD METHODIST SCHOOL (SECONDARY)
# 349                       NGEE ANN SECONDARY SCHOOL
# 350                         SINGAPORE SPORTS SCHOOL
# 351      NUS HIGH SCHOOL OF MATHEMATICS AND SCIENCE
# 352                   SCHOOL OF THE ARTS, SINGAPORE
# 353                               NORTHLIGHT SCHOOL
# 354                       ASSUMPTION PATHWAY SCHOOL
# 355     SCHOOL OF SCIENCE AND TECHNOLOGY, SINGAPORE
# 356                          CREST SECONDARY SCHOOL
# 357                        SPECTRA SECONDARY SCHOOL
#
#                                        url_address  \
# 0                        www.nationaljc.moe.edu.sg
# 1                      http://temasekjc.moe.edu.sg
# 2                   http://www.jurongjc.moe.edu.sg
# 3                                  ajc.moe.edu.sg.
# 4                http://www.victoriajc.moe.edu.sg/
# 5                  http://www.yishunjc.moe.edu.sg/
# 6                      http://www.tpjc.moe.edu.sg/
# 7                       http://www.srjc.moe.edu.sg
# 8                  http://www.pioneerjc.moe.edu.sg
# 9                    http://meridianjc.moe.edu.sg/
# 10                 http://www.innovajc.moe.edu.sg/
# 11                  http://www.eunoiajc.moe.edu.sg
# 12                           http://www.cjc.edu.sg
# 13                          http://www.acjc.edu.sg
# 14              http://www.standrewsjc.moe.edu.sg/
# 15                http://www.nanyangjc.moe.edu.sg/
# 16                      http://www.hwachong.edu.sg
# 17        http://www.millenniainstitute.moe.edu.sg
# 18           http://www.bukitpanjangpri.moe.edu.sg
# 19                 http://www.haiggirls.moe.edu.sg
# 20               http://www.teckwhyepri.moe.edu.sg
# 21                 http://www.jurongpri.moe.edu.sg
# 22             http://www.queenstownpri.moe.edu.sg
# 23                http://www.radinmasps.moe.edu.sg
# 24           http://www.rafflesgirlspri.moe.edu.sg
# 25                    http://www.rosyth.moe.edu.sg
# 26                  http://www.damaipri.moe.edu.sg
# 27                  http://www.fuhuapri.moe.edu.sg
# 28              http://www.woodlandspri.moe.edu.sg
# 29                 http://www.eunospri.moe.edu.sg/
# ..                                             ...
# 328          http://www.christchurchsec.moe.edu.sg
# 329                   http://www.plmgss.moe.edu.sg
# 330                http://www.yuyingsec.moe.edu.sg
# 331  http://www.kuochuanpresbyteriansec.moe.edu.sg
# 332              http://www.sthildassec.moe.edu.sg
# 333                      http://www.mgs.moe.edu.sg
# 334          http://www.haisingcatholic.moe.edu.sg
# 335                               http://acsbr.net
# 336             http://www.anglicanhigh.moe.edu.sg
# 337             http://www.catholichigh.moe.edu.sg
# 338       http://www.chungchenghighmain.moe.edu.sg
# 339     http://www.chungchenghighyishun.moe.edu.sg
# 340        http://www.holyinnocentshigh.moe.edu.sg
# 341          http://www.marisstellahigh.moe.edu.sg
# 342             http://www.nanchiauhigh.moe.edu.sg
# 343                     http://www.nygh.moe.edu.sg
# 344      http://www.chijstnicholasgirls.moe.edu.sg
# 345         HTTP://WWW.MARYMOUNTCONVENT.MOE.EDU.SG
# 346              http://www.manjusrisec.moe.edu.sg
# 347             http://www.presbyterian.moe.edu.sg
# 348                    http://www.fairfieldsec.org
# 349               http://www.ngeeannsec.moe.edu.sg
# 350                 http://www.sportsschool.edu.sg
# 351                             www.nushigh.edu.sg
# 352                        http://www.sota.edu.sg/
# 353                          http://www.nls.edu.sg
# 354                          http://www.aps.edu.sg
# 355                          http://www.sst.edu.sg
# 356                     http://www.crestsec.edu.sg
# 357                             www.spectra.edu.sg
#
#                           address  postal_code          telephone_no  \
# 0               37 HILLCREST ROAD       288913              64661144
# 1             22 BEDOK SOUTH ROAD       469278              64428066
# 2            800 CORPORATION ROAD       649809              65624611
# 3        4500 ANG MO KIO AVENUE 6       569843              64596822
# 4                 20 MARINE VISTA       449035              64485011
# 5              3 YISHUN RING ROAD       768675              62579873
# 6             2 TAMPINES AVENUE 9       529564              67841955
# 7       1033 UPPER SERANGOON ROAD       534768              62850779
# 8               21 TECK WHYE WALK       688258              65646878
# 9          21 PASIR RIS STREET 71       518799              63493660
# 10               21 CHAMPIONS WAY       737902              63983401
# 11            53 MOUNT SINAI ROAD       276880              63518388
# 12               129 WHITLEY ROAD       297822              62524083
# 13            25 DOVER CLOSE EAST       139745              67750511
# 14            5 SORBY ADAMS DRIVE       357691              62857008
# 15         128 SERANGOON AVENUE 3       556111              62842281
# 16           661 BUKIT TIMAH ROAD       269734              64683955
# 17   60 BUKIT BATOK WEST AVENUE 8       658965              63023700
# 18                109 CASHEW ROAD       679676              67691912
# 19              51 KOON SENG ROAD       427072              63440293
# 20              11 TECK WHYE WALK       688261              67691025
# 21      320 JURONG EAST STREET 32       609476              65618837
# 22                310 MARGARET DR       149303              64741044
# 23          1 BUKIT PURMEI AVENUE        99840              62733937
# 24              21 HILLCREST ROAD       289072              64684377
# 25    21 SERANGOON NORTH AVENUE 4       555855              64812273
# 26    52 BEDOK RESERVOIR CRESCENT       479226              64456483
# 27       65 JURONG EAST STREET 13       609647              65624370
# 28          10 WOODLANDS DRIVE 50       738853              62697410
# 29                 95 JALAN EUNOS       419529              67463336
# ..                            ...          ...                   ...
# 328         20 WOODLANDS DRIVE 17       737924              68933297
# 329                296 LOR AH SOO       536742              62816606
# 330           47 HOUGANG AVENUE 1       538884              62827968
# 331           10 BISHAN STREET 13       579795              62593811
# 332          2 TAMPINES STREET 82       528986              63055277
# 333            11 BLACKMORE DRIVE       599986              64694800
# 334           9 PASIR RIS DRIVE 6       519421              65827864
# 335                60 BARKER ROAD       309919              62561633
# 336         600 UPPER CHANGI ROAD       487012              62414866
# 337            9 BISHAN STREET 22       579767  64582177 (Secondary)
# 338               50 GOODMAN ROAD       439012              63441393
# 339           11 YISHUN STREET 61       768547              67583912
# 340     1191 UPPER SERANGOON ROAD       534786              62833381
# 341          25 MOUNT VERNON ROAD       368051       62803880  (Sec)
# 342            20 ANCHORVALE LINK       545079              64897971
# 343                2 LINDEN DRIVE       288683              64663275
# 344      501 ANG MO KIO STREET 13       569405  63541839 (Secondary)
# 345             20 MARYMOUNT ROAD       297754             6256 6701
# 346               20 UBI AVENUE 1       408940              68424558
# 347      5209 ANG MO KIO AVENUE 6       569845              64543722
# 348                102 DOVER ROAD       139649              67788702
# 349          1 TAMPINES STREET 32       529283              67844583
# 350               1 CHAMPIONS WAY       737913              67660100
# 351          20 CLEMENTI AVENUE 1       129957              65161709
# 352            1 ZUBIR SAID DRIVE       227968             6338 9663
# 353               151 TOWNER ROAD       327830          +65 65806490
# 354                30 CASHEW ROAD       679697              68793900
# 355            1 TECHNOLOGY DRIVE       138572         (65) 65717200
# 356     561 JURONG EAST STREET 24       609561              68992779
# 357          1 WOODLANDS DRIVE 64       737758              64660775
#
#           telephone_no_2                fax_no            fax_no_2  \
# 0                     na              64684535                  na
# 1                     na              64428762                  na
# 2                     na              65624505                  na
# 3                     na              64598734                  na
# 4                     na              64438337                  na
# 5                     na              62574373                  na
# 6                     na              67810061                  na
# 7                     na              62825318                  na
# 8                     na              67651861                  na
# 9                     na              63493667                  na
# 10                    na              68943655                  na
# 11                    na              63518399                  na
# 12                    na              62537267                  na
# 13                    na              67775479                  na
# 14              62852007              62850037                  na
# 15                    na              62855147                  na
# 16   64683956 / 64665912              67695857                  na
# 17                    na              63023767                  na
# 18                    na              67637462                  na
# 19                    na              64474169                  na
# 20                    na              67635191                  na
# 21                    na              65641964                  na
# 22                    na              64713640                  na
# 23                    na              62763083                  na
# 24                    na              64692024                  na
# 25                    na              64831102                  na
# 26                    na              64499681                  na
# 27                    na              65639542                  na
# 28                    na              63671165                  na
# 29                    na              67488554                  na
# ..                   ...                   ...                 ...
# 328                   na              68932789                  na
# 329                   na              63820558                  na
# 330                   na              62871607                  na
# 331                   na              63536535                  na
# 332                   na              67865011                  na
# 333                   na              64698717                  na
# 334                   na              65822543                  na
# 335                   na              62561366                  na
# 336                   na              64414690                  na
# 337   64589869 (Primary)  64561322 (Secondary)  64593938 (Primary)
# 338                   na              63449686                  na
# 339                   na              67587397                  na
# 340                   na              62831737                  na
# 341      62827743  (Pri)        62886905 (Sec)      62827905 (Pri)
# 342                   na              64897970                  na
# 343                   na              64667564                  na
# 344   64549698 (Primary)  64511335 (Secondary)  64566169 (Primary)
# 345             62566532              62543080                  na
# 346                   na              67454492                  na
# 347                   na              64543430                  na
# 348                   na              67797482                  na
# 349                   na              67840453                  na
# 350                   na              67662100                  na
# 351                   na              67756910                  na
# 352            6342 5857             6338 9763                  na
# 353                   na         + 65 62912423                  na
# 354                   na              67622857                  na
# 355                   na         (65) 68720856                  na
# 356                   na              68992668                  na
# 357                   na              64623928                  na
#
#                    email_address  \
# 0                 NJC@MOE.EDU.SG
# 1          TEMASEK_JC@MOE.EDU.SG
# 2                 jjc@moe.edu.sg
# 3         anderson_jc@moe.edu.sg
# 4         victoria_jc@moe.edu.sg
# 5           YISHUN_JC@MOE.EDU.SG
# 6                tpjc@moe.edu.sg
# 7                srjc@moe.edu.sg
# 8                 PJC@MOE.EDU.SG
# 9         meridian_jc@moe.edu.sg
# 10          innova_jc@moe.edu.sg
# 11           eunoiajc@moe.edu.sg
# 12        catholic_jc@moe.edu.sg
# 13              acjc@acjc.edu.sg
# 14               sajc@moe.edu.sg
# 15               nyjc@moe.edu.sg
# 16              admin@hci.edu.sg
# 17     millennia_inst@moe.edu.sg
# 18               BPPS@MOE.EDU.SG
# 19       HAIGGIRLSSCH@MOE.EDU.SG
# 20               twps@moe.edu.sg
# 21                JPS@MOE.EDU.SG
# 22               qtps@moe.edu.sg
# 23               rmps@moe.edu.sg
# 24               RGPS@MOE.EDU.SG
# 25         rosyth_sch@moe.edu.sg
# 26           DAMAI_PS@MOE.EDU.SG
# 27               fhps@moe.edu.sg
# 28                wdp@moe.edu.sg
# 29           eunos_ps@moe.edu.sg
# ..                           ...
# 328              ccss@moe.edu.sg
# 329            plmgss@moe.edu.sg
# 330         yuying_ss@moe.edu.sg
# 331             kcpss@moe.edu.sg
# 332              SHSS@MOE.EDU.SG
# 333              MGSS@MOE.EDU.SG
# 334              HSHS@MOE.EDU.SG
# 335             acsbr@moe.edu.sg
# 336               AHS@MOE.EDU.SG
# 337               chs@moe.edu.sg
# 338             CCHMS@MOE.EDU.SG
# 339             cchys@moe.edu.sg
# 340              HIHS@MOE.EDU.SG
# 341               msh@moe.edu.sg
# 342              NCHS@MOE.EDU.SG
# 343             NYGHS@MOE.EDU.SG
# 344       chijsng_sec@moe.edu.sg
# 345              MMCS@MOE.EDU.SG
# 346       manjusri_ss@moe.edu.sg
# 347      presbyterian@moe.edu.sg
# 348              FMSS@MOE.EDU.SG
# 349              nass@moe.edu.sg
# 350  enquire@sportsschool.edu.sg
# 351  einstein@highsch.nus.edu.sg
# 352        enquiries@sota.edu.sg
# 353        NorthLight@ite.edu.sg
# 354               aps@ite.edu.sg
# 355         contactus@sst.edu.sg
# 356         info@crestsec.edu.sg
# 357          info@spectra.edu.sg
#
#                                               mrt_desc  \
# 0    BOTANIC GARDENS MRT, TAN KAH KEE MRT, SIXTH AV...
# 1                                            BEDOK MRT
# 2                                   Lakeside, Boon Lay
# 3                                         Yio Chu Kang
# 4              Nearest MRT Stations:  Kembangan, Eunos
# 5                                       Yishun, Khatib
# 6     Tampines East (operational date to be confirmed)
# 7                                            Kovan MRT
# 8                                        Choa Chu Kang
# 9                                Pasir Ris MRT Station
# 10                                       Woodlands MRT
# 11          Buona Vista MRT Station, Dover MRT Station
# 12   Toa Payoh MRT Station Novena MRT Station Orcha...
# 13                                         Buona Vista
# 14                                   Potong Pasir NE10
# 15   2-minute walk from the Lorong Chuan MRT Statio...
# 16                                     TAN KAH KEE MRT
# 17                                  Bukit Batok (NS-2)
# 18   From Pending LRT station to Choa Chu Kang MRT ...
# 19                                       Eunos, Dakota
# 20                            Chua Chu Kang MRT & LRTs
# 21       Lakeside MRT Station, Jurong East MRT Station
# 22                                      Queenstown MRT
# 23                    Tiong Bahru MRT HarbourFront MRT
# 24                             TAN KAH KEE MRT STATION
# 25                               Ang Mo Kio, Serangoon
# 26                                   Bedok MRT Station
# 27                             JURONG EAST MRT STATION
# 28                                           Woodlands
# 29                         Nearest MRT Station - Eunos
# ..                                                 ...
# 328                                      WOODLANDS MRT
# 329                           KOVAN MRT, SERANGOON MRT
# 330                                          KOVAN MRT
# 331                                         BISHAN MRT
# 332                                       TAMPINES MRT
# 333                               KING ALBERT PARK MRT
# 334                                      PASIR RIS MRT
# 335                            NEWTON MRT, STEVENS MRT
# 336                                    TANAH MERAH MRT
# 337                                         BISHAN MRT
# 338                                         DAKOTA MRT
# 339                                         KHATIB MRT
# 340                                        HOUGANG MRT
# 341                                        BARTLEY MRT
# 342            SENGKANG MRT, RENJONG LRT, TONGKANG LRT
# 343                  SIXTH AVENUE MRT, TAN KAH KEE MRT
# 344                   ANG MO KIO MRT, YIO CHU KANG MRT
# 345     Braddell MRT Station or  Caldecott MRT Station
# 346                 EUNOS MRT, MACPHERSON MRT, UBI MRT
# 347                                   YIO CHU KANG MRT
# 348                     BUONA VISTA MRT, ONE-NORTH MRT
# 349         TAMPINES MRT, SIMEI MRT, TAMPINES EAST MRT
# 350                                      Woodlands MRT
# 351          Nearest MRT Stations - Clementi and Dover
# 352                                        Dhoby Ghaut
# 353                                    BOON KENG (NE9)
# 354                        Downtown Line 2, Cashew mrt
# 355                                              Dover
# 356                   BUKIT BATOK MRT, JURONG EAST MRT
# 357                                      ADMIRALTY MRT
#
#                            ...                            session_code  \
# 0                          ...                                FULL DAY
# 1                          ...                                FULL DAY
# 2                          ...                                FULL DAY
# 3                          ...                                FULL DAY
# 4                          ...                                FULL DAY
# 5                          ...                                FULL DAY
# 6                          ...                                FULL DAY
# 7                          ...                                FULL DAY
# 8                          ...                                FULL DAY
# 9                          ...                                FULL DAY
# 10                         ...                                FULL DAY
# 11                         ...                                FULL DAY
# 12                         ...                                FULL DAY
# 13                         ...                                FULL DAY
# 14                         ...                                FULL DAY
# 15                         ...                                FULL DAY
# 16                         ...                          SINGLE SESSION
# 17                         ...                                FULL DAY
# 18                         ...                          SINGLE SESSION
# 19                         ...                          SINGLE SESSION
# 20                         ...                          SINGLE SESSION
# 21                         ...                          SINGLE SESSION
# 22                         ...                          SINGLE SESSION
# 23                         ...                          SINGLE SESSION
# 24                         ...                          SINGLE SESSION
# 25                         ...                          SINGLE SESSION
# 26                         ...                          SINGLE SESSION
# 27                         ...                          SINGLE SESSION
# 28                         ...                          SINGLE SESSION
# 29                         ...                          SINGLE SESSION
# ..                         ...                                     ...
# 328                        ...                          SINGLE SESSION
# 329                        ...                          SINGLE SESSION
# 330                        ...                          SINGLE SESSION
# 331                        ...                          SINGLE SESSION
# 332                        ...                          SINGLE SESSION
# 333                        ...                          SINGLE SESSION
# 334                        ...                          SINGLE SESSION
# 335                        ...                          SINGLE SESSION
# 336                        ...                          SINGLE SESSION
# 337                        ...                          SINGLE SESSION
# 338                        ...                          SINGLE SESSION
# 339                        ...                          SINGLE SESSION
# 340                        ...                          SINGLE SESSION
# 341                        ...                          SINGLE SESSION
# 342                        ...                          SINGLE SESSION
# 343                        ...                          SINGLE SESSION
# 344                        ...                          SINGLE SESSION
# 345                        ...                          SINGLE SESSION
# 346                        ...                          SINGLE SESSION
# 347                        ...                          SINGLE SESSION
# 348                        ...                          SINGLE SESSION
# 349                        ...                          SINGLE SESSION
# 350                        ...                                FULL DAY
# 351                        ...                                FULL DAY
# 352                        ...                          SINGLE SESSION
# 353                        ...                                FULL DAY
# 354                        ...                          SINGLE SESSION
# 355                        ...                                FULL DAY
# 356                        ...                          SINGLE SESSION
# 357                        ...                          SINGLE SESSION
#
#             mainlevel_code sap_ind autonomous_ind gifted_ind ip_ind  \
# 0              MIXED LEVEL      No             No         No    Yes
# 1              MIXED LEVEL      No             No         No    Yes
# 2           JUNIOR COLLEGE      No             No         No     No
# 3           JUNIOR COLLEGE      No             No         No     No
# 4           JUNIOR COLLEGE      No             No         No    Yes
# 5           JUNIOR COLLEGE      No             No         No     No
# 6           JUNIOR COLLEGE      No             No         No     No
# 7           JUNIOR COLLEGE      No             No         No     No
# 8           JUNIOR COLLEGE      No             No         No     No
# 9           JUNIOR COLLEGE      No             No         No     No
# 10          JUNIOR COLLEGE      No             No         No     No
# 11          JUNIOR COLLEGE      No             No         No    Yes
# 12          JUNIOR COLLEGE      No             No         No     No
# 13          JUNIOR COLLEGE      No             No         No     No
# 14          JUNIOR COLLEGE      No             No         No     No
# 15          JUNIOR COLLEGE      No             No         No     No
# 16             MIXED LEVEL     Yes             No         No    Yes
# 17   CENTRALISED INSTITUTE      No             No         No     No
# 18                 PRIMARY      No             No         No     No
# 19                 PRIMARY      No             No         No     No
# 20                 PRIMARY      No             No         No     No
# 21                 PRIMARY      No             No         No     No
# 22                 PRIMARY      No             No         No     No
# 23                 PRIMARY      No             No         No     No
# 24                 PRIMARY      No             No        Yes     No
# 25                 PRIMARY      No             No        Yes     No
# 26                 PRIMARY      No             No         No     No
# 27                 PRIMARY      No             No         No     No
# 28                 PRIMARY      No             No         No     No
# 29                 PRIMARY      No             No         No     No
# ..                     ...     ...            ...        ...    ...
# 328              SECONDARY      No             No         No     No
# 329              SECONDARY      No            Yes         No     No
# 330              SECONDARY      No             No         No     No
# 331              SECONDARY      No             No         No     No
# 332              SECONDARY      No             No         No     No
# 333              SECONDARY      No             No         No    Yes
# 334              SECONDARY      No             No         No     No
# 335              SECONDARY      No             No         No     No
# 336              SECONDARY     Yes            Yes         No     No
# 337            MIXED LEVEL     Yes            Yes        Yes    Yes
# 338              SECONDARY     Yes            Yes         No     No
# 339              SECONDARY      No             No         No     No
# 340              SECONDARY      No             No         No     No
# 341            MIXED LEVEL     Yes            Yes         No     No
# 342              SECONDARY     Yes             No         No     No
# 343              SECONDARY     Yes             No        Yes    Yes
# 344            MIXED LEVEL     Yes            Yes         No    Yes
# 345                PRIMARY      No             No         No     No
# 346              SECONDARY      No             No         No     No
# 347              SECONDARY      No             No         No     No
# 348              SECONDARY      No            Yes         No     No
# 349              SECONDARY      No            Yes         No     No
# 350            MIXED LEVEL      No             No         No     No
# 351            MIXED LEVEL      No             No         No    Yes
# 352            MIXED LEVEL      No             No         No     No
# 353              SECONDARY      No             No         No     No
# 354              SECONDARY      No             No         No     No
# 355              SECONDARY      No             No         No     No
# 356              SECONDARY      No             No         No     No
# 357              SECONDARY      No             No         No     No
#
#     mothertongue1_code mothertongue2_code mothertongue3_code  \
# 0              Chinese              Malay              Tamil
# 1              Chinese              Malay              Tamil
# 2              Chinese              Malay              Tamil
# 3                   na                 na                 na
# 4              Chinese              Malay              Tamil
# 5                   na                 na                 na
# 6                   na                 na                 na
# 7                   na                 na                 na
# 8              Chinese                 na                 na
# 9              Chinese              Malay              Tamil
# 10             Chinese              Malay              Tamil
# 11             Chinese              Malay              Tamil
# 12                  na                 na                 na
# 13                  na                 na                 na
# 14                  na                 na                 na
# 15                  na                 na                 na
# 16             Chinese                 na                 na
# 17             Chinese              Malay              Tamil
# 18             Chinese              Malay              Tamil
# 19             Chinese              Malay              Tamil
# 20             Chinese              Malay              Tamil
# 21             Chinese              Malay              Tamil
# 22             Chinese              Malay              Tamil
# 23             Chinese              Malay              Tamil
# 24             Chinese              Malay              Tamil
# 25             Chinese              Malay              Tamil
# 26             Chinese              Malay              Tamil
# 27             Chinese              Malay              Tamil
# 28             Chinese              Malay              Tamil
# 29             Chinese              Malay              Tamil
# ..                 ...                ...                ...
# 328            Chinese              Malay              Tamil
# 329            Chinese              Malay              Tamil
# 330            Chinese              Malay              Tamil
# 331            Chinese              Malay              Tamil
# 332            Chinese              Malay              Tamil
# 333            Chinese              Malay              Tamil
# 334            Chinese              Malay              Tamil
# 335            Chinese              Malay              Tamil
# 336            Chinese                 na                 na
# 337            Chinese                 na                 na
# 338            Chinese                 na                 na
# 339            Chinese              Malay              Tamil
# 340            Chinese              Malay              Tamil
# 341            Chinese                 na                 na
# 342            Chinese                 na                 na
# 343            Chinese                 na                 na
# 344            Chinese                 na                 na
# 345            Chinese              Malay              Tamil
# 346            Chinese              Malay                 na
# 347            Chinese              Malay              Tamil
# 348            Chinese              Malay              Tamil
# 349            Chinese              Malay              Tamil
# 350            Chinese              Malay              Tamil
# 351            Chinese              Malay              Tamil
# 352            Chinese              Malay              Tamil
# 353            Chinese              Malay              Tamil
# 354            Chinese              Malay              Tamil
# 355            Chinese              Malay              Tamil
# 356            Chinese              Malay              Tamil
# 357            Chinese              Malay              Tamil
#
#                                    special_sdp_offered
# 0    For the Integrated Programme (Junior High), we...
# 1    TJC 6-Year Integrated Programme provides a sea...
# 2    1. Experiential Learning Programmes (ELP) 2. E...
# 3    Science research, service-learning, student le...
# 4    Arts Programme  Beyond Borders Programme Highe...
# 5    1. Digital art (includes 3D animation, digital...
# 6    Overseas VIA Project, School Twinning Programm...
# 7    Camp ASPIRE:Advanced Student Leadership Progra...
# 8                         Sports and outdoor electives
# 9    Chrystal Programme, Careers & Scholarships Pro...
# 10   Future Readiness Development Programme, Studen...
# 11   Environmental Literacy Programme<br />Leadersh...
# 12   Religious / Ethics Programme Overseas Communit...
# 13   MOE Music and Drama Elective, MOE Humanities a...
# 14   Academic Pacing Programme, University Options ...
# 15   Art Elective Programme (AEP), Language Electiv...
# 16   MOE   Humanities  Programme,  MOE Art Elective...
# 17   MI.World, SkillsFuture, Gap Week, Design Think...
# 18   Learning for Life Programme (LLP) -"i2can danc...
# 19   LLP - Character and Leadership through Perform...
# 20   Teck Whye Primary's Applied Learning Programme...
# 21   JPS is committed to giving each child a broad ...
# 22   In QtPS, the vision of our Character & Citizen...
# 23   Applied Learning Programme: Nurturing 21st Cen...
# 24   ALP: Nurture Confident Communicators<br />LLP:...
# 25   The school offers distinctive programmes in th...
# 26   Learning for Life Programme (LLP), Programme f...
# 27   ICT INFUSION IN TEACHING AND LEARNING,INQUIRY-...
# 28   The school believes that academic and characte...
# 29   Central to the Eunos experience is the emphasi...
# ..                                                 ...
# 328  The school's LLP, Developing Social Emotional ...
# 329  The school has developed a differentiated acad...
# 330  In line with the school's vision, 'Enterprisin...
# 331  The school offers a Learning for Life programm...
# 332  The school's Applied Learning Programme 'iTHin...
# 333  MGS is a dual track school with an Integrated ...
# 334  Hai Sing Catholic School's Applied Learning Pr...
# 335  1:1 Learning Programme, Aesthetics Programme, ...
# 336  In Anglican High School (AHS) where 'Talents S...
# 337  CHS' model of Leader-Gentleman-Bilingual Schol...
# 338  (1) Special Assistance Plan (SAP) School Progr...
# 339  The school's Learning for Life Programme 'Deve...
# 340  We offer the Applied Learning Programme in 'Jo...
# 341  The Marcellin Programme, anchored in Marist va...
# 342  Our SAP Bicultural & Flagship Programme is des...
# 343  Nanyang Seal of Excellence Talent Development ...
# 344  Our Joint Integrated Programme, developed coll...
# 345  We aim to raise our daughters of Marymount by ...
# 346  The school has adopted the Building Learning P...
# 347  The school leverages on its Learning for Life ...
# 348  Aligned with the WHEEL philosophy, and the dev...
# 349  Ngee Ann Secondary offers a plethora of learni...
# 350  Academy sports: Badminton, Bowling, Fencing, F...
# 351  Boarding Da Vinci Einstein + (NUS High School ...
# 352                                                 na
# 353  NorthLight Programme, Sports & Wellness Progra...
# 354  Montfort Development Programme, iSTAY (Residen...
# 355  The SST Student Development Programme envision...
# 356  Vocational Taster Modules (TMs) and ISC Subjec...
# 357  The school's customised Instructional Curricul...
#
# [358 rows x 35 columns]

# %%
full_sch_address_list = school_address_df["address"].unique().tolist()
len(full_sch_address_list)
# Out:
# 357

# %% [markdown]
# There are 357 schools recorded in the dataset ```school_address_df```.

# %%
# %%time
import requests

sch_query_results = []
querystring = {}

for x in full_sch_address_list:
    url = "https://developers.onemap.sg/commonapi/search"
    

    querystring.update({"searchVal":x,"returnGeom":"Y","getAddrDetails":"Y","pageNum":"1"})
    #print (querystring['searchVal'])
    
    payload = "------WebKitFormBoundary7MA4YWxkTrZu0gW\r\nContent-Disposition: form-data; name=\"searchVal\"\r\n\r\n\r\n------WebKitFormBoundary7MA4YWxkTrZu0gW\r\nContent-Disposition: form-data; name=\"returnGeom {Y/N}\"\r\n\r\n\r\n------WebKitFormBoundary7MA4YWxkTrZu0gW\r\nContent-Disposition: form-data; name=\"getAddrDetails {Y/N}\"\r\n\r\n\r\n------WebKitFormBoundary7MA4YWxkTrZu0gW\r\nContent-Disposition: form-data; name=\"pageNum\"\r\n\r\n\r\n------WebKitFormBoundary7MA4YWxkTrZu0gW--"
    headers = {
    'content-type': "multipart/form-data; boundary=----WebKitFormBoundary7MA4YWxkTrZu0gW",
    'Cache-Control': "no-cache",
    'Postman-Token': "5f4af03e-410e-4b28-93bc-05006b4de49a"
    }

    response = requests.request("GET", url, data=payload, headers=headers, params=querystring)
    

    sch_query_results.append(response.json())

#print(response.text)
print('Search Done.')
# Out:
# Search Done.
# Wall time: 8min 47s

# %%
sch_latlong_df = pd.DataFrame()
for entry in range(len(sch_query_results)):
    temp_df = pd.DataFrame.from_dict(sch_query_results[entry]['results'])
    sch_latlong_df = sch_latlong_df.append(temp_df)

# %%
sch_latlong_df.head(1)
# Out:
#                                              ADDRESS BLK_NO  \
# 0  37 HILLCREST ROAD NATIONAL JUNIOR COLLEGE SING...     37
#
#                   BUILDING          LATITUDE         LONGITUDE  \
# 0  NATIONAL JUNIOR COLLEGE  1.33029291072176  103.804110905425
#
#          LONGTITUDE  POSTAL       ROAD_NAME                SEARCHVAL  \
# 0  103.804110905425  288913  HILLCREST ROAD  NATIONAL JUNIOR COLLEGE
#
#                   X                Y
# 0  24749.4869699031  34722.567163026

# %%
# Concatenate latitude and longitude columns into one column
sch_latlong_df["lat_long"] = sch_latlong_df["LATITUDE"] +' '+ sch_latlong_df["LONGITUDE"]

# convert lat_long column to tuples
sch_latlong_df["lat_long"] = sch_latlong_df["lat_long"].apply(lambda x: tuple(x.split(' ')))

# %%
sch_latlong_df.reset_index()

# convert the lat_long column in station_latlong_df to a list
sch_latlong_list = list(sch_latlong_df.T.iloc[-1,:])

# %%
# %%time
sch_distance_df = pd.DataFrame(latlong_df["lat_long"])
for x in sch_latlong_list:
    sch_distance_df[x] = latlong_df['lat_long'].apply(lambda y: geopy.distance.vincenty(y, x).km)
# Out:
# Wall time: 3min 44s

# %%
# get the distance from each address to the nearest station
sch_distance_df['distance_to_nearest_sch'] = sch_distance_df.iloc[:,1:].apply(lambda x: min(x), axis=1)

# %%
sch_distance_df = sch_distance_df.iloc[:,[0,-1]]
sch_distance_df.head(1)
# Out:
#                                lat_long  distance_to_nearest_sch
# 0  (1.36619678831055, 103.841505011903)                 0.145364

# %%
# Merge our results into the main hdb address dataframe: latlong_df
latlong_df_final = pd.merge(latlong_df_final, sch_distance_df, on='lat_long', how='left')

# %%
latlong_df_final.dtypes
# Out:
# ADDRESS                         object
# BLK_NO                          object
# BUILDING                        object
# LATITUDE                        object
# LONGITUDE                       object
# LONGTITUDE                      object
# POSTAL                          object
# ROAD_NAME                       object
# SEARCHVAL                       object
# X                               object
# Y                               object
# full_address                    object
# lat_long                        object
# distance_to_nearest_station    float64
# distance_to_nearest_sch        float64
# dtype: object

# %%
latlong_df_final.head(1)
# Out:
#                                              ADDRESS BLK_NO       BUILDING  \
# 0  216 ANG MO KIO AVENUE 1 ANG MO KIO 22 SINGAPOR...    216  ANG MO KIO 22
#
#            LATITUDE         LONGITUDE        LONGTITUDE  POSTAL  \
# 0  1.36619678831055  103.841505011903  103.841505011903  560216
#
#              ROAD_NAME      SEARCHVAL                 X                Y  \
# 0  ANG MO KIO AVENUE 1  ANG MO KIO 22  28911.0522399386  38692.616790574
#
#               full_address                              lat_long  \
# 0  216 ANG MO KIO AVENUE 1  (1.36619678831055, 103.841505011903)
#
#    distance_to_nearest_station  distance_to_nearest_sch
# 0                     0.954205                 0.145364

# %%
latlong_df_final = latlong_df_final.iloc[:,[-4,3,4,-1,-2,-3]]

# %%
latlong_df_final.head(1)
# Out:
#               full_address          LATITUDE         LONGITUDE  \
# 0  216 ANG MO KIO AVENUE 1  1.36619678831055  103.841505011903
#
#    distance_to_nearest_sch  distance_to_nearest_station  \
# 0                 0.145364                     0.954205
#
#                                lat_long
# 0  (1.36619678831055, 103.841505011903)

# %%
# Save it as csv file
#latlong_df_final.to_csv('data/latlong_df_final.csv')
latlong_df_final = pd.read_csv("data/latlong_df_final.csv")

# %% [markdown]
# ---

# %% [markdown]
# ## Extra Information on HDB Blocks

# %% [markdown]
# We also want to include some extra information regarding on HDB blocks. This was taken from [data.gov.sg/hdb-property-information](https://data.gov.sg/dataset/hdb-property-information).

# %%
hdb_extra_df = pd.read_csv("data/hdb-property-information.csv")

# %%
hdb_extra_df.head(1)
# Out:
#   blk_no         street  max_floor_lvl  year_completed residential commercial  \
# 0     60  SENG POH LANE              1            1937           N          Y
#
#   market_hawker miscellaneous multistorey_carpark precinct_pavilion  \
# 0             N             N                   N                 N
#
#          ...         3room_sold  4room_sold  5room_sold  exec_sold  \
# 0        ...                  0           0           0          0
#
#    multigen_sold  studio_apartment_sold  1room_rental  2room_rental  \
# 0              0                      0             0             0
#
#    3room_rental  other_room_rental
# 0             0                  0
#
# [1 rows x 24 columns]

# %%
hdb_extra_df.dtypes
# Out:
# blk_no                   object
# street                   object
# max_floor_lvl             int64
# year_completed            int64
# residential              object
# commercial               object
# market_hawker            object
# miscellaneous            object
# multistorey_carpark      object
# precinct_pavilion        object
# bldg_contract_town       object
# total_dwelling_units      int64
# 1room_sold                int64
# 2room_sold                int64
# 3room_sold                int64
# 4room_sold                int64
# 5room_sold                int64
# exec_sold                 int64
# multigen_sold             int64
# studio_apartment_sold     int64
# 1room_rental              int64
# 2room_rental              int64
# 3room_rental              int64
# other_room_rental         int64
# dtype: object

# %% [markdown]
# Observe that definitely not all features are useful for modeling.

# %%
hdb_extra_df['full_address'] = hdb_extra_df["blk_no"].map(str) + ' ' + hdb_extra_df["street"].map(str)

# %%
# Filter out instances that are not commercial buildings
hdb_extra_df = hdb_extra_df[hdb_extra_df["commercial"]=='N']

# Select columns that may be useful in modeling
hdb_extra_df_final = hdb_extra_df.iloc[:,[-1,2,3,4,6,7,8,9]]

# %%
hdb_extra_df_final.head(1)
# Out:
#       full_address  max_floor_lvl  year_completed residential market_hawker  \
# 8  48 MOH GUAN TER              4            1949           Y             N
#
#   miscellaneous multistorey_carpark precinct_pavilion
# 8             Y                   N                 N

# %%
# Save it as csv file
hdb_extra_df_final.to_csv('data/latlong_df_final.csv')

# %%
hdb_extra_df_final.shape
# Out:
# (9559, 8)

# %% [markdown]
# ---

# %% [markdown]
# ## Final Merge

# %% [markdown]
# The data preprocessing stage is often tedious. We should take extra caution when dealing with merging tasks. The column names must match between dataframes, and even entries inside each of them have to be investigated for any spelling errors or typos or mismatchs.
#
# We found that ```latlong_df_final``` contain addresses in their full form, whereas the concocatenated dataframe ```df``` has address with abbreviations. We have to make sure all full forms strings are rename into their corresponding abbreviations. I figured out the abbreviations by eyeballing the addresses.

# %%
latlong_df_final['full_address'] = latlong_df_final['full_address'].str.replace('AVENUE', 'AVE') \
                                    .str.replace('CRESCENT', 'CRES') \
                                    .str.replace('ROAD', 'RD') \
                                    .str.replace('STREET', 'ST') \
                                    .str.replace('CENTRAL', 'CTRL') \
                                    .str.replace('HEIGHTS', 'HTS') \
                                    .str.replace('TERRACE', 'TER') \
                                    .str.replace('JALAN', 'JLN') \
                                    .str.replace('DRIVE', 'DR') \
                                    .str.replace('PLACE', 'PL') \
                                    .str.replace('CLOSE', 'CL') \
                                    .str.replace('PARK', 'PK') \
                                    .str.replace('GARDENS', 'GDNS') \
                                    .str.replace('NORTH', 'NTH') \
                                    .str.replace('SOUTH', 'STH') \
                                    .str.replace('BUKIT', 'BT') \
                                    .str.replace('UPPER', 'UPP}') \
                                    .str.replace('COMMONWEALTH', "C'WEALTH") \

# %%
latlong_df_final_nodup = latlong_df_final.drop_duplicates('full_address')

# %%
del latlong_df_final_nodup["Unnamed: 0"]

# %%
df_final = pd.merge(df, latlong_df_final_nodup, on='full_address', how='left')

# %%
df_final = pd.merge(df_final, hdb_extra_df_final, on='full_address', how='left')

# %%
df_final.head(1)
# Out:
#   block flat_model flat_type  floor_area_sqm  lease_commence_date    month  \
# 0   309   IMPROVED    1 ROOM            31.0                 1977  1990-01
#
#    resale_price storey_range       street_name        town  \
# 0        9000.0     10 TO 12  ANG MO KIO AVE 1  ANG MO KIO
#
#            full_address  LATITUDE  LONGITUDE  distance_to_nearest_sch  \
# 0  309 ANG MO KIO AVE 1       NaN        NaN                      NaN
#
#    distance_to_nearest_station lat_long  max_floor_lvl  year_completed  \
# 0                          NaN      NaN            NaN             NaN
#
#   residential market_hawker miscellaneous multistorey_carpark  \
# 0         NaN           NaN           NaN                 NaN
#
#   precinct_pavilion
# 0               NaN

# %%
# Thanks to https://stackoverflow.com/a/39734251
def missing_values_table(df):
        mis_val = df.isnull().sum()
        mis_val_percent = 100 * df.isnull().sum() / len(df)
        mis_val_table = pd.concat([mis_val, mis_val_percent], axis=1)
        mis_val_table_ren_columns = mis_val_table.rename(
        columns = {0 : 'Missing Values', 1 : '% of Total Values'})
        mis_val_table_ren_columns = mis_val_table_ren_columns[
            mis_val_table_ren_columns.iloc[:,1] != 0].sort_values(
        '% of Total Values', ascending=False).round(1)
        print ("Your selected dataframe has " + str(df.shape[1]) + " columns.\n"      
            "There are " + str(mis_val_table_ren_columns.shape[0]) +
              " columns that have missing values.")
        return mis_val_table_ren_columns

# %%
missing_values_table(df_final)
# Out:
# Your selected dataframe has 23 columns.
# There are 12 columns that have missing values.
#                              Missing Values  % of Total Values
# max_floor_lvl                        760400               24.5
# year_completed                       760400               24.5
# residential                          760400               24.5
# market_hawker                        760400               24.5
# miscellaneous                        760400               24.5
# multistorey_carpark                  760400               24.5
# precinct_pavilion                    760400               24.5
# LATITUDE                             156896                5.1
# LONGITUDE                            156896                5.1
# distance_to_nearest_sch              156896                5.1
# distance_to_nearest_station          156896                5.1
# lat_long                             156896                5.1

# %% [markdown]
# The above dataframe spells bad news. The new data that we imported, ```hdb_extra_df```, does not have records of 24.5% of address in our original dataframe. I certainly did not expect this. Note that for some of the features, 5.1% of the rows has missing values. Once again this can be attributed to the same reason, ```latlong_df``` does not have records of some addresses in our original dataframe.

# %%
# Create year and month features
df_final['year'] = df_final1['month'].apply(lambda x: x.split('-')[0])
df_final['month'] = df_final1['month'].apply(lambda x: x.split('-')[1])

# %% [markdown]
# ---

# %% [markdown]
# ## COE data

# %%
coe_df = pd.read_csv("data/coe-results.csv")

# %%
coe_df.head()
# Out:
#      month  bidding_no vehicle_class  quota  bids_success  bids_received  \
# 0  2010-01           1    Category A   1152          1145           1342
# 1  2010-01           1    Category B    687           679            883
# 2  2010-01           1    Category C    173           173            265
# 3  2010-01           1    Category D    373           365            509
# 4  2010-01           1    Category E    586           567           1011
#
#    premium
# 0    18502
# 1    19190
# 2    19001
# 3      889
# 4    19889

# %%
coe_df['year'] = coe_df['month'].apply(lambda x: x.split('-')[0])
coe_df['month'] = coe_df['month'].apply(lambda x: x.split('-')[1])

# %%
coe_df['month'] = pd.to_numeric(coe_df['month'])

# %%
coe_df['year_month'] = coe_df['year'].map(str) + '-' + coe_df['month'].map(str)

# %%
coe_prem_df = coe_df.groupby(["year_month"])['premium'].mean().reset_index()

# %%
coe_prem_df.head()
# Out:
#   year_month  premium
# 0     2010-1  16321.3
# 1    2010-10  30652.9
# 2    2010-11  32744.5
# 3    2010-12  43799.2
# 4     2010-2  18077.2

# %%
# Save it as csv file
coe_prem_df.to_csv('data/coe_prem_df.csv')
#df_final = pd.read_csv("data/df_final.csv")

# %% [markdown]
# ---

# %% [markdown]
# ## Final Touchups

# %% [markdown]
# Some final touchups on our data before we ship it to tableau.

# %%
df_final['flat_type'].unique()
# Out:
# array(['1 ROOM', '3 ROOM', '4 ROOM', '5 ROOM', '2 ROOM', 'EXECUTIVE',
#        'MULTI GENERATION', 'MULTI-GENERATION'], dtype=object)

# %%
df_final['flat_type'] = df_final['flat_type'].str.replace('MULTI-GENERATION', 'MULTI GENERATION')

# %%
df_final['flat_type'].unique()
# Out:
# array(['1 ROOM', '3 ROOM', '4 ROOM', '5 ROOM', '2 ROOM', 'EXECUTIVE',
#        'MULTI GENERATION'], dtype=object)

# %%
df_final.head()
# Out:
#    Unnamed: 0 block      flat_model flat_type  floor_area_sqm  \
# 0           0   309        IMPROVED    1 ROOM            31.0
# 1           1   309        IMPROVED    1 ROOM            31.0
# 2           2   309        IMPROVED    1 ROOM            31.0
# 3           3   309        IMPROVED    1 ROOM            31.0
# 4           4   216  NEW GENERATION    3 ROOM            73.0
#
#    lease_commence_date  month  resale_price storey_range       street_name  \
# 0                 1977      1        9000.0     10 TO 12  ANG MO KIO AVE 1
# 1                 1977      1        6000.0     04 TO 06  ANG MO KIO AVE 1
# 2                 1977      1        8000.0     10 TO 12  ANG MO KIO AVE 1
# 3                 1977      1        6000.0     07 TO 09  ANG MO KIO AVE 1
# 4                 1976      1       47200.0     04 TO 06  ANG MO KIO AVE 1
#
#          town          full_address  LATITUDE   LONGITUDE  \
# 0  ANG MO KIO  309 ANG MO KIO AVE 1       NaN         NaN
# 1  ANG MO KIO  309 ANG MO KIO AVE 1       NaN         NaN
# 2  ANG MO KIO  309 ANG MO KIO AVE 1       NaN         NaN
# 3  ANG MO KIO  309 ANG MO KIO AVE 1       NaN         NaN
# 4  ANG MO KIO  216 ANG MO KIO AVE 1  1.366197  103.841505
#
#    distance_to_nearest_sch  distance_to_nearest_station  \
# 0                      NaN                          NaN
# 1                      NaN                          NaN
# 2                      NaN                          NaN
# 3                      NaN                          NaN
# 4                 0.145364                     0.954205
#
#                                    lat_long  max_floor_lvl  year_completed  \
# 0                                       NaN            NaN             NaN
# 1                                       NaN            NaN             NaN
# 2                                       NaN            NaN             NaN
# 3                                       NaN            NaN             NaN
# 4  ('1.36619678831055', '103.841505011903')           10.0          1975.0
#
#   residential market_hawker miscellaneous multistorey_carpark  \
# 0         NaN           NaN           NaN                 NaN
# 1         NaN           NaN           NaN                 NaN
# 2         NaN           NaN           NaN                 NaN
# 3         NaN           NaN           NaN                 NaN
# 4           Y             N             N                   N
#
#   precinct_pavilion  year
# 0               NaN  1990
# 1               NaN  1990
# 2               NaN  1990
# 3               NaN  1990
# 4                 N  1990

# %%
df_final.shape
# Out:
# (3100996, 25)

# %%
df_final = df_final.dropna(subset=['lat_long'])

# %%
df_final["lat_long"] = df_final["LATITUDE"].map(str) +' '+ df_final["LONGITUDE"].map(str)
# convert lat_long column to tuples
df_final["lat_long"] = df_final["lat_long"].apply(lambda x: tuple(x.split(' ')))

# %%
# %%time
# The coordinates for central area is taken from 
# https://tools.wmflabs.org/geohack/geohack.php?pagename=Central_Region,_Singapore&params=1_18_2.04_N_103_49_17.97_E_type:city(939890)_region:SG

df_final['distance_to_city'] = df_final['lat_long'].apply(lambda y: geopy.distance.vincenty((1.300567, 103.821658), y).km)
# Out:
# Wall time: 1min 24s

# %%
df_final['distance_to_city'].describe()
# Out:
# count    2.944100e+06
# mean     1.119336e+01
# std      3.966534e+00
# min      1.089058e+00
# 25%      8.574658e+00
# 50%      1.172617e+01
# 75%      1.448055e+01
# max      2.089332e+01
# Name: distance_to_city, dtype: float64

# %% [markdown]
# ## Fixing ```flat_model``` Feature

# %% [markdown]
# The feature ```flat_model``` has lots of similar unmatched words and groups that are too small to consider as a categories. We need to rename them one by one and group small groups into one bigger category. We put small groups into a big category mainly because we don't want the dimensionality to be large. If unhandled, it can make the training of models slower, although it does not cause more of a problem in other aspects.

# %%
list(df_final['flat_model'].unique())
# Out:
# ['NEW GENERATION',
#  'STANDARD',
#  'IMPROVED',
#  'MODEL A',
#  'SIMPLIFIED',
#  'MODEL A-MAISONETTE',
#  'APARTMENT',
#  'MAISONETTE',
#  'ADJOINED FLAT',
#  'TERRACE',
#  '2-ROOM',
#  'IMPROVED-MAISONETTE',
#  'MULTI GENERATION',
#  'PREMIUM APARTMENT',
#  'New Generation',
#  'Improved',
#  'Model A',
#  'Standard',
#  'Apartment',
#  'Model A-Maisonette',
#  'Maisonette',
#  'Simplified',
#  'Multi Generation',
#  'Adjoined flat',
#  'Premium Apartment',
#  'Terrace',
#  'Improved-Maisonette',
#  'Premium Maisonette',
#  '2-room',
#  'Model A2',
#  'Type S1',
#  'Type S2',
#  'DBSS',
#  'Premium Apartment Loft',
#  'Premium Apartment.']

# %%
df_final['flat_model'] = df_final['flat_model'].str.replace('Model A-MAISONETTE', 'Maisonette') \
                                    .str.replace('APARTMENT', 'Apartment') \
                                    .str.replace('MAISONETTE', 'Maisonette') \
                                    .str.replace('IMPROVED', 'Improved') \
                                    .str.replace('SIMPLIFIED', 'Simplified') \
                                    .str.replace('MODEL A-MAISONETTE', 'Maisonette') \
                                    .str.replace('Improved-Maisonette', 'Maisonette') \
                                    .str.replace('Premium Maisonette', 'Maisonette') \
                                    .str.replace('ADJOINED FLAT', 'Adjoined flat') \
                                    .str.replace('TERRACE', 'Terrace') \
                                    .str.replace('2-ROOM', '2-room') \
                                    .str.replace('MULTI GENERATION', 'Multi Generation') \
                                    .str.replace('PREMIUM APARTMENT', 'Premium Apartment') \
                                    .str.replace('Premium Apartment.', 'Premium Apartment') \
                                    .str.replace('Premium Apartment Loft', 'Premium Apartment') \
                                    .str.replace('NEW GENERATION', 'New Generation') \
                                    .str.replace('MODEL A', 'Model A') \
                                    .str.replace('Improved-MAISONETTE', 'Maisonette') \
                                    .str.replace('Model A-Maisonette', 'Maisonette') \
                                    .str.replace('Premium ApartmentLoft', 'Premium Apartment')

# %%
df_final['flat_model'].value_counts()
# Out:
# Model A              828236
# Improved             721208
# New Generation       663536
# Simplified           207088
# Apartment            118832
# Premium Apartment    118620
# Maisonette           106492
# Standard              74412
# STANDARD              57132
# Model A2              33940
# Adjoined flat          6644
# Terrace                2444
# DBSS                   2300
# Multi Generation       1884
# Type S1                 796
# Type S2                 364
# 2-room                  148
# PREMIUM Apartment        24
# Name: flat_model, dtype: int64

# %% [markdown]
# We missed some unmatched words. Let's put the 7 smallest groups into a category 'misc'.

# %%
df_final['flat_model'] = df_final['flat_model'].str.replace('Model A-MAISONETTE', 'Maisonette') \
                                    .str.replace('PREMIUM Apartment', 'Premium Apartment') \
                                    .str.replace('APARTMENT', 'Apartment') \
                                    .str.replace('MAISONETTE', 'Maisonette') \
                                    .str.replace('2-room', 'misc') \
                                    .str.replace('Type S2', 'misc') \
                                    .str.replace('Type S1', 'misc') \
                                    .str.replace('Multi Generation', 'misc') \
                                    .str.replace('Terrace', 'misc') \
                                    .str.replace('DBSS', 'misc')

# %%
df_final['flat_model'].value_counts()
# Out:
# Model A              828236
# Improved             721208
# New Generation       663536
# Simplified           207088
# Apartment            118832
# Premium Apartment    118644
# Maisonette           106492
# Standard              74412
# STANDARD              57132
# Model A2              33940
# misc                   7936
# Adjoined flat          6644
# Name: flat_model, dtype: int64

# %% [markdown]
# ## Final Look at Dataset

# %%
df_final.head(2)
# Out:
#    Unnamed: 0 block      flat_model flat_type  floor_area_sqm  \
# 4           4   216  New Generation    3 ROOM            73.0
# 5           5   211  New Generation    3 ROOM            67.0
#
#    lease_commence_date  month  resale_price storey_range       street_name  \
# 4                 1976      1       47200.0     04 TO 06  ANG MO KIO AVE 1
# 5                 1977      1       46000.0     01 TO 03  ANG MO KIO AVE 3
#
#          town          full_address  LATITUDE   LONGITUDE  \
# 4  ANG MO KIO  216 ANG MO KIO AVE 1  1.366197  103.841505
# 5  ANG MO KIO  211 ANG MO KIO AVE 3  1.369197  103.841667
#
#    distance_to_nearest_sch  distance_to_nearest_station  \
# 4                 0.145364                     0.954205
# 5                 0.181780                     0.867154
#
#                                  lat_long  max_floor_lvl  year_completed  \
# 4    (1.36619678831055, 103.841505011903)           10.0          1975.0
# 5  (1.3691969656170402, 103.841666636086)            NaN             NaN
#
#   residential market_hawker miscellaneous multistorey_carpark  \
# 4           Y             N             N                   N
# 5         NaN           NaN           NaN                 NaN
#
#   precinct_pavilion  year  distance_to_city
# 4                 N  1990          7.585695
# 5               NaN  1990          7.908701

# %% [markdown]
# ## Saving...

# %%
# Save it as csv file
df_final.to_csv('data/df_final.csv')
#df_final = pd.read_csv("data/df_final.csv")

# %%
df_final.head()
# Out:
#    Unnamed: 0 block      flat_model flat_type  floor_area_sqm  \
# 4           4   216  New Generation    3 ROOM            73.0
# 5           5   211  New Generation    3 ROOM            67.0
# 6           6   202  New Generation    3 ROOM            67.0
# 7           7   235  New Generation    3 ROOM            67.0
# 8           8   235  New Generation    3 ROOM            67.0
#
#    lease_commence_date  month  resale_price storey_range       street_name  \
# 4                 1976      1       47200.0     04 TO 06  ANG MO KIO AVE 1
# 5                 1977      1       46000.0     01 TO 03  ANG MO KIO AVE 3
# 6                 1977      1       42000.0     07 TO 09  ANG MO KIO AVE 3
# 7                 1977      1       38000.0     10 TO 12  ANG MO KIO AVE 3
# 8                 1977      1       40000.0     04 TO 06  ANG MO KIO AVE 3
#
#          town          full_address  LATITUDE   LONGITUDE  \
# 4  ANG MO KIO  216 ANG MO KIO AVE 1  1.366197  103.841505
# 5  ANG MO KIO  211 ANG MO KIO AVE 3  1.369197  103.841667
# 6  ANG MO KIO  202 ANG MO KIO AVE 3  1.368446  103.844516
# 7  ANG MO KIO  235 ANG MO KIO AVE 3  1.366824  103.836491
# 8  ANG MO KIO  235 ANG MO KIO AVE 3  1.366824  103.836491
#
#    distance_to_nearest_sch  distance_to_nearest_station  \
# 4                 0.145364                     0.954205
# 5                 0.181780                     0.867154
# 6                 0.000000                     0.560273
# 7                 0.203720                     1.471209
# 8                 0.203720                     1.471209
#
#                                  lat_long  max_floor_lvl  year_completed  \
# 4    (1.36619678831055, 103.841505011903)           10.0          1975.0
# 5  (1.3691969656170402, 103.841666636086)            NaN             NaN
# 6     (1.3684464401094, 103.844516260527)            NaN             NaN
# 7     (1.36682360872345, 103.83649123351)           12.0          1976.0
# 8     (1.36682360872345, 103.83649123351)           12.0          1976.0
#
#   residential market_hawker miscellaneous multistorey_carpark  \
# 4           Y             N             N                   N
# 5         NaN           NaN           NaN                 NaN
# 6         NaN           NaN           NaN                 NaN
# 7           Y             N             Y                   N
# 8           Y             N             Y                   N
#
#   precinct_pavilion  year  distance_to_city year_month
# 4                 N  1990          7.585695     1990-1
# 5               NaN  1990          7.908701     1990-1
# 6               NaN  1990          7.925137     1990-1
# 7                 N  1990          7.509993     1990-1
# 8                 N  1990          7.509993     1990-1

# %%
df_final['year_month'] = df_final['year'].map(str) + '-' + df_final['month'].map(str)

# %%
df_final.columns
# Out:
# Index(['Unnamed: 0', 'block', 'flat_model', 'flat_type', 'floor_area_sqm',
#        'lease_commence_date', 'month', 'resale_price', 'storey_range',
#        'street_name', 'town', 'full_address', 'LATITUDE', 'LONGITUDE',
#        'distance_to_nearest_sch', 'distance_to_nearest_station', 'lat_long',
#        'max_floor_lvl', 'year_completed', 'residential', 'market_hawker',
#        'miscellaneous', 'multistorey_carpark', 'precinct_pavilion', 'year',
#        'distance_to_city', 'year_month'],
#       dtype='object')
